# %% [markdown]
# <a href="https://colab.research.google.com/github/Cracko34/Cracko34/blob/main/Copia_de_Pre_Entrega_Ejemplo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pre-Entrega
#
# * **Curso:** Data Analytics con Python
# * **Comisión:** 25261
# * **Alumno:**
# * **Fecha:**
#
#
# **Objetivo:** Explorar, limpiar, transformar e integrar datos de ventas, clientes y marketing para analizar desempeño de productos y efectividad de campañas.
#
# ### NOTA:
# No se ha respetado el orden de las actividades, para conseguir un mejor resultado.
#
#
# **Etapa 1: Recopilación y Preparación de Datos (Clases 1 a 4)**
#
# **Etapa 2: Preprocesamiento y Limpieza de Datos (Clases 5 a 8)**
#
# **Actividades (orden):**
#
# * 1.1. Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.
#   * *1.4. Introducción a Pandas: realizar un análisis exploratorio inicial de los Dataframes.*
#   * *1.5. Calidad de Datos: Identificar valores nulos y duplicados en los conjuntos de datos. Documentar el estado inicial de los datos.*
#   * *2.1. Limpieza de Datos: Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados.*
# * 1.2. Realizar un script básico que calcule las ventas mensuales utilizando variables y operadores.
# * 1.3. Estructuras de Datos: Desarrollar un programa que almacene los datos de ventas (producto, precio, cantidad). Decidir si conviene utilizar diccionarios o listas.
# * 2.2. Transformación de Datos: Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.
# * 2.3. Agregación: Resumir las ventas por categoría de producto y analizar los ingresos generados.
# * 2.4. ~Integración de Datos: Combinar los sets de datos de ventas y marketing para obtener una visión más amplia de las tendencias.~

# %% [markdown]
# ## Etapa 1 - Actividad 1:
#
# ***Crear un documento en Google Colaboratory y cargar los sets de datos como DataFrames.***

# %%
# ----------------------------------------------------
# Importamos módulos (Librerías basicas)
# ----------------------------------------------------
import pandas as pd
import numpy as np

# ----------------------------------------------------
# Cargamos los DataFrames
# ----------------------------------------------------
ventas    = pd.read_csv("ventas.csv")
clientes  = pd.read_csv("clientes.csv")
marketing = pd.read_csv("marketing.csv")

# ----------------------------------------------------
# Obtenemos una vista rápida
# ----------------------------------------------------
print("ventas:", ventas.shape)
print("clientes:", clientes.shape)
print("marketing:", marketing.shape)
# Out:
# ventas: (3035, 6)
# clientes: (567, 5)
# marketing: (90, 6)

# %% [markdown]
# Al leer los archivos, obtuvimos:
#
# - **ventas:** `(3035, 6)`: **3035 filas** (transacciones registradas) y **6 columnas** (atributos por venta, p. ej., fecha, producto, precio, cantidad).
# - **clientes:** `(567, 5)`: **567 filas** (clientes únicos) y **5 columnas** (características del cliente para segmentación/análisis).
# - **marketing:** `(90, 6)` : **90 filas** (campañas o acciones de marketing) y **6 columnas** (atributos de la campaña, como canal, fechas, objetivos, etc.).
#
# > Esta verificación confirma el **volumen** y la **estructura básica** de los datasets antes de explorar su contenido. A partir de aquí podremos planear el **preprocesamiento** (fechas, precios, duplicados, nulos).
#
# ---
# # FUERA DE ORDEN
#
# ## Etapa 1 - Actividad 4 y 5
#
# ***Introducción a Pandas:** realizar un análisis exploratorio inicial de los
# DataFrames.*
#
# ***Calidad de Datos:** Identificar valores nulos y duplicados en los conjuntos de
# datos. Documentar el estado inicial de los datos.*
#
# Realizaremos:
# - `shape` y `info()` para revisar **dimensiones y tipos de datos**,
# - `head()` para inspección **muestral**,
# - `describe()` para un **resumen estadístico** inicial.
#
# Con estos resultados vamos a decidir:
# - Qué columnas necesitan **conversión de tipos** (fechas/numéricos),
# - Cómo trataremos **caracteres no deseados** (p. ej., `$`, comas),
# - Y si existen **duplicados o nulos** relevantes a documentar.

# %%
# ----------------------------------------------------
# Exploración inicial
# ----------------------------------------------------

# ----------------------------------------------------
# Dado que tenemos que "explorar" tres dataframes,
# escribo una función que haga lo necesario, y luego
# la uso con cada uno de los dataframes.
# ----------------------------------------------------
def explorar_simple(df, nombre):
    print()
    print("-"*40)
    print(f"{nombre.upper()} ")
    print("-"*40)

    # ------------------------------------------------
    # Tamaño y tipos de datos
    # ------------------------------------------------
    print("Shape (filas, columnas):", df.shape)
    print("\nTipos de datos:")
    print(df.dtypes)

    # ------------------------------------------------
    # "Calidad" del dataframe (nulos, duplicados, etc)
    # ------------------------------------------------
    print()
    print("-"*40)
    print("Nulos por columna")
    print("-"*40)
    print(df.isna().sum())
    print()
    print("-"*40)
    print("Duplicados (filas exactas):", df.duplicated().sum())
    print("-"*40)

    # ------------------------------------------------
    # Muestra rápida del contenido
    # ------------------------------------------------
    print()
    print("-"*40)
    print("Primeras 5 filas")
    print("-"*40)
    display(df.head(5))

    # ------------------------------------------------
    # Resumen numérico y categórico
    # por separado para evitar problemas de versión
    # ------------------------------------------------
    print()
    num = df.select_dtypes(include="number")
    if not num.empty:
        print("-"*40)
        print("Resumen numérico")
        print("-"*40)
        # .T es para transponer y ver cada columna como fila (más cómodo).
        display(num.describe().T)
    else:
        print("-"*40)
        print("Resumen numérico")
        print("No hay columnas numéricas)")
        print("-"*40)

    cat = df.select_dtypes(include="object")
    if not cat.empty:
        print("-"*40)
        print("Resumen categórico")
        print("-"*40)
        display(cat.describe().T)
    else:
        print("-"*40)
        print("Resumen categórico")
        print("No hay columnas categóricas)")
        print("-"*40)

# Ejecutar para cada dataset
explorar_simple(ventas, "ventas")
# Out:
# ----------------------------------------
# VENTAS
# ----------------------------------------
# Shape (filas, columnas): (3035, 6)
#
# Tipos de datos:
# id_venta         int64
# producto        object
# precio          object
# cantidad       float64
# fecha_venta     object
# categoria       object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_venta       0
# producto       0
# precio         2
# cantidad       2
# fecha_venta    0
# categoria      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 35
# ----------------------------------------
#
# ----------------------------------------
# Primeras 5 filas
# ----------------------------------------
#    id_venta           producto   precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   $69.94       5.0  02/01/2024
# 1       811    Lámpara de mesa  $105.10       5.0  02/01/2024
# 2      1156           Secadora   $97.96       3.0  02/01/2024
# 3      1372           Heladera  $114.35       8.0  02/01/2024
# 4      1546           Secadora  $106.21       4.0  02/01/2024
#
#            categoria
# 0         Decoración
# 1         Decoración
# 2  Electrodomésticos
# 3  Electrodomésticos
# 4  Electrodomésticos
# ----------------------------------------
# Resumen numérico
# ----------------------------------------
#            count         mean         std  min    25%     50%     75%     max
# id_venta  3035.0  1499.851400  866.465379  1.0  748.5  1502.0  2249.5  3000.0
# cantidad  3033.0     6.496538    3.457250  1.0    3.0     7.0     9.0    12.0
# ----------------------------------------
# Resumen categórico
# ----------------------------------------
#             count unique              top  freq
# producto     3035     30  Lámpara de mesa   181
# precio       3033   2590           $76.32     5
# fecha_venta  3035    364       06/04/2024    24
# categoria    3035      3       Decoración  1015

# %%
# ----------------------------------------------------
# Lo hacemos con clientes
# ----------------------------------------------------
explorar_simple(clientes, "clientes")
# Out:
# ----------------------------------------
# CLIENTES
# ----------------------------------------
# Shape (filas, columnas): (567, 5)
#
# Tipos de datos:
# id_cliente      int64
# nombre         object
# edad            int64
# ciudad         object
# ingresos      float64
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_cliente    0
# nombre        0
# edad          0
# ciudad        0
# ingresos      0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------
#
# ----------------------------------------
# Primeras 5 filas
# ----------------------------------------
#    id_cliente               nombre  edad         ciudad  ingresos
# 0           1      Aloysia Screase    44  Mar del Plata  42294.68
# 1           2  Kristina Scaplehorn    25        Posadas  24735.04
# 2           3       Filip Castagne    50    Resistencia  35744.85
# 3           4          Liuka Luard    39   Bahía Blanca  27647.96
# 4           5        Dore Cockshtt    28        Rosario  28245.65
# ----------------------------------------
# Resumen numérico
# ----------------------------------------
#             count          mean           std     min       25%       50%  \
# id_cliente  567.0    284.000000    163.823075    1.00    142.50    284.00
# edad        567.0     37.940035     10.202885   20.00     30.00     37.00
# ingresos    567.0  34668.739012  12974.531446  170.29  26015.24  35066.83
#
#                 75%       max
# id_cliente    425.5    567.00
# edad           43.0     81.00
# ingresos    42457.1  88053.01
# ----------------------------------------
# Resumen categórico
# ----------------------------------------
#        count unique            top freq
# nombre   567    567    Micah Matis    1
# ciudad   567     12  Mar del Plata   63

# %%
# ----------------------------------------------------
# Y con "marketing"
# ----------------------------------------------------
explorar_simple(marketing, "marketing")
# Out:
# ----------------------------------------
# MARKETING
# ----------------------------------------
# Shape (filas, columnas): (90, 6)
#
# Tipos de datos:
# id_campanha       int64
# producto         object
# canal            object
# costo           float64
# fecha_inicio     object
# fecha_fin        object
# dtype: object
#
# ----------------------------------------
# Nulos por columna
# ----------------------------------------
# id_campanha     0
# producto        0
# canal           0
# costo           0
# fecha_inicio    0
# fecha_fin       0
# dtype: int64
#
# ----------------------------------------
# Duplicados (filas exactas): 0
# ----------------------------------------
#
# ----------------------------------------
# Primeras 5 filas
# ----------------------------------------
#    id_campanha         producto  canal  costo fecha_inicio   fecha_fin
# 0           74  Adorno de pared     TV   4.81   20/03/2024  03/05/2024
# 1           12           Tablet   RRSS   3.40   26/03/2024  13/05/2024
# 2           32  Lámpara de mesa  Email   5.54   28/03/2024  20/04/2024
# 3           21       Smartphone   RRSS   6.37   29/03/2024  16/05/2024
# 4           58         Alfombra  Email   4.25   31/03/2024  05/05/2024
# ----------------------------------------
# Resumen numérico
# ----------------------------------------
#              count       mean        std   min      25%   50%      75%    max
# id_campanha   90.0  45.500000  26.124701  1.00  23.2500  45.5  67.7500  90.00
# costo         90.0   4.928667   0.947750  2.95   4.3725   4.9   5.5625   7.39
# ----------------------------------------
# Resumen categórico
# ----------------------------------------
#              count unique              top freq
# producto        90     30  Adorno de pared    3
# canal           90      3               TV   30
# fecha_inicio    90     78       25/09/2024    2
# fecha_fin       90     78       05/05/2024    3

# %% [markdown]
# # FUERA DE ORDEN
# Hacemos este punto ahora, asi podemos avanzar con un dataset limpio...
#
#
# ## Etapa 2 - Actividad 1
# ***Limpieza de Datos:* Limpiar el conjunto de datos eliminando duplicados y caracteres no deseados. Documentar el proceso y los resultados**
#
# **Hallazgos clave de la exploración:**
# - `ventas.precio` está como **texto** con símbolo `$` : convertir a número.
# - `ventas.fecha_venta` y `marketing.fecha_inicio/fecha_fin` están como **texto** (formato `dd/mm/aaaa`) : convertir a `datetime` con `dayfirst=True`.
# - `ventas.cantidad` tiene **2 nulos** y `ventas.precio` **2 nulos** : estas filas no permiten calcular el importe.
# - `ventas` tiene **35 filas duplicadas exactas**.
#
# **Decisiones (documentadas):**
# 1. **Estandarizar precios**: quitar `$` y convertir a `float`.
# 2. **Parsear fechas** con `dayfirst=True` (formato local).
# 3. **Filtrar nulos críticos**: eliminar filas con `precio` o `cantidad` nulo (no se puede calcular el importe).
# 4. **Eliminar duplicados** exactos en `ventas`.
# 5. **Crear `importe = precio * cantidad`** para análisis posteriores.
#
# > Nota: preferimos **eliminar** nulos críticos en esta primera entrega para mantener integridad de métricas. En una versión avanzada podríamos imputar, pero aquí priorizamos transparencia y reproducibilidad.

# %%
# ----------------------------------------------------
# 0) Controles previos
# Estos datos nos van a servir luego para escribir la
# bitácora o resúmen de nuestras acciones, justificar
# decisiones, etc.
# ----------------------------------------------------

prev_shape = ventas.shape
prev_nulos_precio   = ventas['precio'].isna().sum()
prev_nulos_cantidad = ventas['cantidad'].isna().sum()
prev_dup            = ventas.duplicated().sum()

print("-"*40)
print("Antes de limpiar")
print("-"*40)
print("shape:", prev_shape,
      "| nulos precio:", prev_nulos_precio,
      "| nulos cantidad:", prev_nulos_cantidad,
      "| duplicados:", prev_dup)
# Out:
# ----------------------------------------
# Antes de limpiar
# ----------------------------------------
# shape: (3035, 6) | nulos precio: 2 | nulos cantidad: 2 | duplicados: 35

# %%
# ----------------------------------------------------
# 1) Normalizar 'precio' (string a float)
# ----------------------------------------------------
if 'precio' in ventas.columns:
    ventas['precio'] = (ventas['precio']
                        .astype(str)
                        .str.replace(r'[$,\s]', '', regex=True)
                        .replace({'nan': np.nan}))   # respeta nulos reales
    ventas['precio'] = pd.to_numeric(ventas['precio'], errors='coerce')

# %%
# ----------------------------------------------------
# 2) Parsear fechas en "ventas" y "marketing"
# ----------------------------------------------------
if 'fecha_venta' in ventas.columns:
    ventas['fecha_venta'] = pd.to_datetime(ventas['fecha_venta'], dayfirst=True, errors='coerce')

for col in ['fecha_inicio', 'fecha_fin']:
    if col in marketing.columns:
        marketing[col] = pd.to_datetime(marketing[col], dayfirst=True, errors='coerce')

# %%
# ----------------------------------------------------
# 3) Eliminar filas con nulos críticos en "ventas"
#    (columnas "precio" y "cantidad")
# ----------------------------------------------------
mask_validos = ventas['precio'].notna() & ventas['cantidad'].notna()
eliminados_nulos = (~mask_validos).sum()
ventas = ventas[mask_validos].copy()

# %%
# ----------------------------------------------------
# 4) Eliminar duplicados exactos en ventas
# ----------------------------------------------------
len_antes = len(ventas)
ventas = ventas.drop_duplicates().copy()
len_despues = len(ventas)
dup_eliminados = len_antes - len_despues
print("Duplicados eliminados:", dup_eliminados)
# Out:
# Duplicados eliminados: 0

# %%
# ----------------------------------------------------
# 5) Crear importe
# ----------------------------------------------------
ventas['importe'] = ventas['precio'] * ventas['cantidad']

# %%
# ----------------------------------------------------
# 6) Reporte post-limpieza
# ----------------------------------------------------
print("-"*40)
print("Después de limpiar")
print("-"*40)
print("shape:", ventas.shape)
print("Filas eliminadas por nulos críticos (precio/cantidad):", eliminados_nulos)
print("Duplicados eliminados:", dup_eliminados)
# Out:
# ----------------------------------------
# Después de limpiar
# ----------------------------------------
# shape: (2998, 7)
# Filas eliminadas por nulos críticos (precio/cantidad): 2
# Duplicados eliminados: 0

# %%
# ----------------------------------------------------
# 7) Chequeo rápido
# ----------------------------------------------------
print("-"*40)
print("Chequeo rápido (post):")
print("-"*40)
print("nulos importe:", ventas['importe'].isna().sum())
print("rango fechas ventas:", ventas['fecha_venta'].min(), "a", ventas['fecha_venta'].max())

# Vista mínima
print()
display(ventas.head(3))
# Out:
# ----------------------------------------
# Chequeo rápido (post):
# ----------------------------------------
# nulos importe: 0
# rango fechas ventas: 2024-01-02 00:00:00 a 2024-12-30 00:00:00
#    id_venta           producto  precio  cantidad fecha_venta  \
# 0       792  Cuadro decorativo   69.94       5.0  2024-01-02
# 1       811    Lámpara de mesa  105.10       5.0  2024-01-02
# 2      1156           Secadora   97.96       3.0  2024-01-02
#
#            categoria  importe
# 0         Decoración   349.70
# 1         Decoración   525.50
# 2  Electrodomésticos   293.88

# %% [markdown]
# # VOLVEMOS AL ORDEN "NORMAL"
#
# ## Etapa 1 - Actividad 2
#
# *Realizar un **script básico** que calcule las ventas mensuales utilizando variables y operadores.*
#
#
# Vamos a sumar las ventas por mes usando **variables, operadores y un bucle**, evitando funciones de agregación como `groupby` o `pivot_table`.
#
# **Pasos:**
#
# 1. **Preparación:** el DataFrame `ventas` ya tiene `fecha_venta` como `datetime64`
#
# 2. Creamos la columna `importe` (`precio * cantidad`).
#
# 3. **Acumulador:** creamos un diccionario llamado `totales`. La **clave** será una **tupla** `(año, mes)` y el **valor** el total acumulado de `importe`.
#
# 4. **Recorrido:** iteramos las filas con `itertuples()` y, para cada fila válida:
#
#    * Obtenemos `año = fecha_venta.year` y `mes = fecha_venta.month`.
#    * Hacemos `totales[(año, mes)] += importe`.
#    * Si la fila tiene `fecha_venta` o `importe` nulos, la **omitimos**.
#
# 4. **Orden y salida:** ordenamos las claves `(año, mes)` y mostramos un listado tipo `YYYY-MM: $ total`. También reportamos cuántas filas **procesamos** y cuántas **omitimos**.
#
# **Notas:**
#
# * Si hay varios años mezclados, funciona igual (la clave `(año, mes)` los separa).
# * Si hubiera importes negativos (devoluciones), se suman tal cual. Si queremos excluirlos, agregariamos algo como `if importe > 0:` antes de acumular.

# %%
# ----------------------------------------------------
# Configuración (opcional): nombres de meses para
# imprimir al final un reporte más legible.
# ----------------------------------------------------
MESES_NOMBRE = {
    1:"Enero", 2:"Febrero", 3:"Marzo", 4:"Abril",
    5:"Mayo", 6:"Junio", 7:"Julio", 8:"Agosto",
    9:"Septiembre", 10:"Octubre", 11:"Noviembre", 12:"Diciembre"
}

# ----------------------------------------------------
# Diccionario acumulador por (año, mes)
# ----------------------------------------------------
totales = {}

# ----------------------------------------------------
# Contadores de control (Siempre ayuda tener info
# extra para realizar una pequeña para auditoría
# simple al final)
# ----------------------------------------------------
filas_procesadas = 0
filas_omitidas = 0

# ----------------------------------------------------
# Validaciones: chequear que existan las columnas clave
# (Sabemos que están, pero lo hacemos como práctica)
# ----------------------------------------------------
if not {"fecha_venta", "importe"}.issubset(ventas.columns):
    print()
    print("-"*40)
    print("ERROR: Faltan columnas requeridas")
    print("-"*40)

# ----------------------------------------------------
# Recorrer el DataFrame fila por fila
# ----------------------------------------------------
for fila in ventas.itertuples(index=False):
    # Acceso por atributo, con el nombres exacto de las columnas
    # (Si no existe la columna, devuelve NaT/nan)
    fecha = getattr(fila, "fecha_venta", pd.NaT)
    importe = getattr(fila, "importe", np.nan)

    # Omitimos filas con fecha/importe inválidos
    if pd.isna(fecha) or pd.isna(importe):
        filas_omitidas += 1
        continue

    # Esto es por si queremos excluir importes <= 0:
    # if importe <= 0:
    #     filas_omitidas += 1
    #     continue

    # Clave (año, mes) y acumulación
    clave = (fecha.year, fecha.month)  # p.ej., (2024, 3)
    totales[clave] = totales.get(clave, 0.0) + float(importe)
    filas_procesadas += 1

# ----------------------------------------------------
# Ordenar resultados por año y mes
# ----------------------------------------------------
claves_ordenadas = sorted(totales.keys())

# Imprimir resultados
print()
print("-"*40)
print("Ventas mensuales")
print("-"*40)
for (anio, mes) in claves_ordenadas:
    total = totales[(anio, mes)]
    # Formato: YYYY-MM y nombre del mes
    etiqueta_mes = f"{anio}-{mes:02d} ({MESES_NOMBRE.get(mes, str(mes))})"
    print(f"{etiqueta_mes}: $ {total:.2f}")

print()
print("-"*40)
print("Resumen de control")
print(f"Filas procesadas: {filas_procesadas}")
print(f"Filas omitidas  : {filas_omitidas}")
print("-"*40)

# ----------------------------------------------------
# (Opcional) Si queremos un DataFrame de salida lo
# construimos "a mano" a partir del diccionario
# ----------------------------------------------------

resumen_rows = [
    {"anio": anio, "mes": mes, "mes_nombre": MESES_NOMBRE.get(mes, str(mes)), "total_ventas": totales[(anio, mes)]}
    for (anio, mes) in claves_ordenadas
]
resumen_df = pd.DataFrame(resumen_rows, columns=["anio", "mes", "mes_nombre", "total_ventas"])

# Orden amigable por (anio, mes)
resumen_df = resumen_df.sort_values(["anio", "mes"], ascending=[True, True]).reset_index(drop=True)

print()
print("-"*40)
print("Dataframe resumen")
print("-"*40)
display(resumen_df)
# Out:
# ----------------------------------------
# Ventas mensuales
# ----------------------------------------
# 2024-01 (Enero): $ 129604.99
# 2024-02 (Febrero): $ 118672.44
# 2024-03 (Marzo): $ 136779.15
# 2024-04 (Abril): $ 128430.69
# 2024-05 (Mayo): $ 143727.25
# 2024-06 (Junio): $ 108480.17
# 2024-07 (Julio): $ 116229.97
# 2024-08 (Agosto): $ 119680.15
# 2024-09 (Septiembre): $ 115787.85
# 2024-10 (Octubre): $ 112117.13
# 2024-11 (Noviembre): $ 119951.79
# 2024-12 (Diciembre): $ 117631.94
#
# ----------------------------------------
# Resumen de control
# Filas procesadas: 2998
# Filas omitidas  : 0
# ----------------------------------------
#
# ----------------------------------------
# Dataframe resumen
# ----------------------------------------
#     anio  mes  mes_nombre  total_ventas
# 0   2024    1       Enero     129604.99
# 1   2024    2     Febrero     118672.44
# 2   2024    3       Marzo     136779.15
# 3   2024    4       Abril     128430.69
# 4   2024    5        Mayo     143727.25
# 5   2024    6       Junio     108480.17
# 6   2024    7       Julio     116229.97
# 7   2024    8      Agosto     119680.15
# 8   2024    9  Septiembre     115787.85
# 9   2024   10     Octubre     112117.13
# 10  2024   11   Noviembre     119951.79
# 11  2024   12   Diciembre     117631.94

# %% [markdown]
# ## Etapa 1 - Actividad 3
#
# ***Estructuras de Datos:** Desarrollar un programa que almacene los datos de
# ventas (producto, precio, cantidad).*
#
# *Decidir si conviene utilizar diccionarios o listas*
#
#
# **Solución posible:**
# Elijo usar una lista de diccionarios. Es una estructura simple, que me sirve para iterar, filtrar o calcular totales con un bucle si es necesario. El código tambien es **muy sencillo**:
#
#
#
#
# * `registros = []`
#   Crea una **lista vacía** donde guardo cada venta como un diccionario.
#
# * `for fila in ventas.itertuples(index=False):`
#   Recorre el DataFrame **fila por fila** usando tuplas con **acceso por atributo** (`fila.precio`, `fila.cantidad`, etc.). `index=False` evita incluir el índice en la tupla.
#
# * Dentro del bucle se **valida** que los tres campos obligatorios no sean nulos. Si falta alguno, se **salta** esa fila.
#
# * `registros.append({...})`
#   construye un **diccionario** con las 3 claves (`producto`, `precio`, `cantidad`) y lo agrega a la lista.
#   Se usa `float(...)` para asegurar que `precio` y `cantidad` queden en **numérico** (útil para cálculos posteriores).
#
# Resultado: `registros` queda como una **lista de diccionarios**.

# %%
# ----------------------------------------------------
# Iteramos por el dataset, armando una lista de
# diccionarios con el contenido pedido.
# ----------------------------------------------------
registros = []
for fila in ventas.itertuples(index=False):
    if pd.isna(fila.precio) or pd.isna(fila.cantidad) or pd.isna(fila.producto):
        continue
    registros.append({
        "producto": fila.producto,
        "precio": float(fila.precio),
        "cantidad": float(fila.cantidad),
    })

# ----------------------------------------------------
# No se pide mostrarlos, pero queremos "ver" que tiene
# la estructura que creamos...
# ----------------------------------------------------
display(registros)
# Out:
# [{'producto': 'Cuadro decorativo', 'precio': 69.94, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 105.1, 'cantidad': 5.0},
#  {'producto': 'Secadora', 'precio': 97.96, 'cantidad': 3.0},
#  {'producto': 'Heladera', 'precio': 114.35, 'cantidad': 8.0},
#  {'producto': 'Secadora', 'precio': 106.21, 'cantidad': 4.0},
#  {'producto': 'Horno eléctrico', 'precio': 35.35, 'cantidad': 9.0},
#  {'producto': 'Plancha de vapor', 'precio': 65.43, 'cantidad': 2.0},
#  {'producto': 'Proyector', 'precio': 88.17, 'cantidad': 9.0},
#  {'producto': 'Rincón de plantas', 'precio': 79.86, 'cantidad': 11.0},
#  {'producto': 'Candelabro', 'precio': 66.11, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 95.9, 'cantidad': 5.0},
#  {'producto': 'Freidora eléctrica', 'precio': 111.18, 'cantidad': 1.0},
#  {'producto': 'Aspiradora', 'precio': 70.91, 'cantidad': 2.0},
#  {'producto': 'Proyector', 'precio': 43.62, 'cantidad': 11.0},
#  {'producto': 'Tablet', 'precio': 67.97, 'cantidad': 9.0},
#  {'producto': 'Tablet', 'precio': 74.09, 'cantidad': 5.0},
#  {'producto': 'Cortinas', 'precio': 62.1, 'cantidad': 4.0},
#  {'producto': 'Adorno de pared', 'precio': 71.99, 'cantidad': 9.0},
#  {'producto': 'Jarrón decorativo', 'precio': 96.97, 'cantidad': 7.0},
#  {'producto': 'Cuadro decorativo', 'precio': 101.92, 'cantidad': 9.0},
#  {'producto': 'Candelabro', 'precio': 90.7, 'cantidad': 12.0},
#  {'producto': 'Lavadora', 'precio': 28.41, 'cantidad': 10.0},
#  {'producto': 'Freidora eléctrica', 'precio': 122.25, 'cantidad': 11.0},
#  {'producto': 'Proyector', 'precio': 32.15, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 86.82, 'cantidad': 8.0},
#  {'producto': 'Cortinas', 'precio': 106.66, 'cantidad': 11.0},
#  {'producto': 'Jarrón decorativo', 'precio': 57.22, 'cantidad': 9.0},
#  {'producto': 'Heladera', 'precio': 109.49, 'cantidad': 11.0},
#  {'producto': 'Auriculares', 'precio': 84.8, 'cantidad': 10.0},
#  {'producto': 'Cámara digital', 'precio': 107.78, 'cantidad': 3.0},
#  {'producto': 'Lavadora', 'precio': 38.99, 'cantidad': 6.0},
#  {'producto': 'Cafetera', 'precio': 61.4, 'cantidad': 9.0},
#  {'producto': 'Consola de videojuegos', 'precio': 102.57, 'cantidad': 9.0},
#  {'producto': 'Cámara digital', 'precio': 50.76, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 87.05, 'cantidad': 5.0},
#  {'producto': 'Auriculares', 'precio': 100.4, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 108.48, 'cantidad': 11.0},
#  {'producto': 'Espejo decorativo', 'precio': 82.76, 'cantidad': 8.0},
#  {'producto': 'Adorno de pared', 'precio': 57.62, 'cantidad': 6.0},
#  {'producto': 'Cuadro decorativo', 'precio': 30.49, 'cantidad': 12.0},
#  {'producto': 'Candelabro', 'precio': 34.23, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 33.63, 'cantidad': 10.0},
#  {'producto': 'Plancha de vapor', 'precio': 26.91, 'cantidad': 5.0},
#  {'producto': 'Secadora', 'precio': 95.33, 'cantidad': 11.0},
#  {'producto': 'Aspiradora', 'precio': 65.55, 'cantidad': 8.0},
#  {'producto': 'Plancha de vapor', 'precio': 51.51, 'cantidad': 7.0},
#  {'producto': 'Auriculares', 'precio': 116.04, 'cantidad': 11.0},
#  {'producto': 'Smartphone', 'precio': 107.51, 'cantidad': 5.0},
#  {'producto': 'Consola de videojuegos', 'precio': 29.49, 'cantidad': 2.0},
#  {'producto': 'Jarrón decorativo', 'precio': 37.05, 'cantidad': 4.0},
#  {'producto': 'Candelabro', 'precio': 57.65, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 27.68, 'cantidad': 8.0},
#  {'producto': 'Cortinas', 'precio': 32.57, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 50.86, 'cantidad': 4.0},
#  {'producto': 'Smartphone', 'precio': 54.19, 'cantidad': 12.0},
#  {'producto': 'Smartphone', 'precio': 70.07, 'cantidad': 11.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 87.78, 'cantidad': 1.0},
#  {'producto': 'SmartWatch', 'precio': 82.18, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 85.71, 'cantidad': 8.0},
#  {'producto': 'Candelabro', 'precio': 47.22, 'cantidad': 5.0},
#  {'producto': 'Espejo decorativo', 'precio': 60.39, 'cantidad': 2.0},
#  {'producto': 'Jarrón decorativo', 'precio': 42.46, 'cantidad': 8.0},
#  {'producto': 'Lámpara de mesa', 'precio': 79.64, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 29.88, 'cantidad': 10.0},
#  {'producto': 'Microondas', 'precio': 67.39, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 99.58, 'cantidad': 7.0},
#  {'producto': 'Horno eléctrico', 'precio': 68.53, 'cantidad': 8.0},
#  {'producto': 'Batidora', 'precio': 39.26, 'cantidad': 11.0},
#  {'producto': 'Cámara digital', 'precio': 120.87, 'cantidad': 7.0},
#  {'producto': 'Alfombra', 'precio': 122.07, 'cantidad': 9.0},
#  {'producto': 'Espejo decorativo', 'precio': 96.29, 'cantidad': 9.0},
#  {'producto': 'Elementos de cerámica', 'precio': 106.31, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 67.23, 'cantidad': 10.0},
#  {'producto': 'Jarrón decorativo', 'precio': 42.83, 'cantidad': 5.0},
#  {'producto': 'Plancha de vapor', 'precio': 66.15, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 36.38, 'cantidad': 5.0},
#  {'producto': 'Microondas', 'precio': 46.05, 'cantidad': 6.0},
#  {'producto': 'Rincón de plantas', 'precio': 31.7, 'cantidad': 11.0},
#  {'producto': 'Rincón de plantas', 'precio': 29.88, 'cantidad': 8.0},
#  {'producto': 'Jarrón decorativo', 'precio': 87.84, 'cantidad': 7.0},
#  {'producto': 'Espejo decorativo', 'precio': 32.34, 'cantidad': 5.0},
#  {'producto': 'Horno eléctrico', 'precio': 119.7, 'cantidad': 6.0},
#  {'producto': 'Aspiradora', 'precio': 36.89, 'cantidad': 7.0},
#  {'producto': 'Batidora', 'precio': 79.98, 'cantidad': 12.0},
#  {'producto': 'Lavadora', 'precio': 120.75, 'cantidad': 10.0},
#  {'producto': 'SmartWatch', 'precio': 48.45, 'cantidad': 2.0},
#  {'producto': 'Auriculares', 'precio': 117.43, 'cantidad': 11.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 29.89, 'cantidad': 9.0},
#  {'producto': 'Espejo decorativo', 'precio': 55.61, 'cantidad': 1.0},
#  {'producto': 'Freidora eléctrica', 'precio': 52.57, 'cantidad': 11.0},
#  {'producto': 'SmartWatch', 'precio': 115.0, 'cantidad': 10.0},
#  {'producto': 'Smartphone', 'precio': 67.93, 'cantidad': 10.0},
#  {'producto': 'Consola de videojuegos', 'precio': 110.6, 'cantidad': 12.0},
#  {'producto': 'Rincón de plantas', 'precio': 109.33, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 35.2, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 111.1, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 96.79, 'cantidad': 5.0},
#  {'producto': 'Elementos de cerámica', 'precio': 102.62, 'cantidad': 3.0},
#  {'producto': 'Cafetera', 'precio': 35.73, 'cantidad': 12.0},
#  {'producto': 'Televisor', 'precio': 57.34, 'cantidad': 1.0},
#  {'producto': 'Tablet', 'precio': 32.3, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 90.21, 'cantidad': 2.0},
#  {'producto': 'Espejo decorativo', 'precio': 115.45, 'cantidad': 7.0},
#  {'producto': 'Rincón de plantas', 'precio': 64.67, 'cantidad': 10.0},
#  {'producto': 'Espejo decorativo', 'precio': 98.26, 'cantidad': 1.0},
#  {'producto': 'Lavadora', 'precio': 43.98, 'cantidad': 6.0},
#  {'producto': 'Batidora', 'precio': 96.78, 'cantidad': 12.0},
#  {'producto': 'Cafetera', 'precio': 123.96, 'cantidad': 9.0},
#  {'producto': 'Lavadora', 'precio': 84.8, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 27.36, 'cantidad': 10.0},
#  {'producto': 'Lámpara de mesa', 'precio': 76.32, 'cantidad': 9.0},
#  {'producto': 'Cortinas', 'precio': 118.69, 'cantidad': 9.0},
#  {'producto': 'Adorno de pared', 'precio': 101.48, 'cantidad': 9.0},
#  {'producto': 'Elementos de cerámica', 'precio': 74.35, 'cantidad': 5.0},
#  {'producto': 'Freidora eléctrica', 'precio': 119.46, 'cantidad': 2.0},
#  {'producto': 'SmartWatch', 'precio': 75.65, 'cantidad': 5.0},
#  {'producto': 'Laptop', 'precio': 31.69, 'cantidad': 1.0},
#  {'producto': 'Consola de videojuegos', 'precio': 99.14, 'cantidad': 6.0},
#  {'producto': 'SmartWatch', 'precio': 30.38, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 95.73, 'cantidad': 5.0},
#  {'producto': 'Tablet', 'precio': 117.47, 'cantidad': 2.0},
#  {'producto': 'Espejo decorativo', 'precio': 75.93, 'cantidad': 10.0},
#  {'producto': 'Espejo decorativo', 'precio': 101.91, 'cantidad': 3.0},
#  {'producto': 'Cuadro decorativo', 'precio': 30.59, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 40.97, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 98.55, 'cantidad': 6.0},
#  {'producto': 'Freidora eléctrica', 'precio': 83.95, 'cantidad': 8.0},
#  {'producto': 'Plancha de vapor', 'precio': 86.65, 'cantidad': 6.0},
#  {'producto': 'Proyector', 'precio': 107.98, 'cantidad': 6.0},
#  {'producto': 'Consola de videojuegos', 'precio': 31.57, 'cantidad': 1.0},
#  {'producto': 'Cámara digital', 'precio': 38.37, 'cantidad': 9.0},
#  {'producto': 'Proyector', 'precio': 115.19, 'cantidad': 11.0},
#  {'producto': 'Auriculares', 'precio': 80.29, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 58.32, 'cantidad': 10.0},
#  {'producto': 'Rincón de plantas', 'precio': 81.5, 'cantidad': 1.0},
#  {'producto': 'Rincón de plantas', 'precio': 87.4, 'cantidad': 9.0},
#  {'producto': 'Jarrón decorativo', 'precio': 106.89, 'cantidad': 6.0},
#  {'producto': 'Plancha de vapor', 'precio': 94.53, 'cantidad': 2.0},
#  {'producto': 'Tablet', 'precio': 69.35, 'cantidad': 4.0},
#  {'producto': 'Televisor', 'precio': 117.53, 'cantidad': 9.0},
#  {'producto': 'SmartWatch', 'precio': 76.47, 'cantidad': 7.0},
#  {'producto': 'Adorno de pared', 'precio': 81.76, 'cantidad': 5.0},
#  {'producto': 'Rincón de plantas', 'precio': 80.17, 'cantidad': 3.0},
#  {'producto': 'Secadora', 'precio': 102.73, 'cantidad': 6.0},
#  {'producto': 'Plancha de vapor', 'precio': 45.14, 'cantidad': 1.0},
#  {'producto': 'Proyector', 'precio': 84.1, 'cantidad': 11.0},
#  {'producto': 'Auriculares', 'precio': 63.67, 'cantidad': 5.0},
#  {'producto': 'Cámara digital', 'precio': 119.43, 'cantidad': 5.0},
#  {'producto': 'Laptop', 'precio': 81.74, 'cantidad': 10.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 69.4, 'cantidad': 1.0},
#  {'producto': 'Televisor', 'precio': 84.96, 'cantidad': 5.0},
#  {'producto': 'Adorno de pared', 'precio': 76.92, 'cantidad': 6.0},
#  {'producto': 'Lámpara de mesa', 'precio': 52.95, 'cantidad': 6.0},
#  {'producto': 'Jarrón decorativo', 'precio': 103.13, 'cantidad': 8.0},
#  {'producto': 'Espejo decorativo', 'precio': 123.21, 'cantidad': 7.0},
#  {'producto': 'Alfombra', 'precio': 33.48, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 85.23, 'cantidad': 6.0},
#  {'producto': 'Lavadora', 'precio': 97.73, 'cantidad': 12.0},
#  {'producto': 'Cafetera', 'precio': 98.21, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 27.45, 'cantidad': 10.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 42.98, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 69.47, 'cantidad': 8.0},
#  {'producto': 'Rincón de plantas', 'precio': 85.75, 'cantidad': 3.0},
#  {'producto': 'Horno eléctrico', 'precio': 98.42, 'cantidad': 8.0},
#  {'producto': 'Batidora', 'precio': 95.59, 'cantidad': 3.0},
#  {'producto': 'Cámara digital', 'precio': 108.61, 'cantidad': 2.0},
#  {'producto': 'SmartWatch', 'precio': 83.01, 'cantidad': 11.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 40.74, 'cantidad': 6.0},
#  {'producto': 'Cámara digital', 'precio': 71.45, 'cantidad': 5.0},
#  {'producto': 'Cámara digital', 'precio': 91.13, 'cantidad': 8.0},
#  {'producto': 'Lámpara de mesa', 'precio': 121.72, 'cantidad': 8.0},
#  {'producto': 'Jarrón decorativo', 'precio': 91.53, 'cantidad': 12.0},
#  {'producto': 'Horno eléctrico', 'precio': 103.57, 'cantidad': 1.0},
#  {'producto': 'Plancha de vapor', 'precio': 27.61, 'cantidad': 7.0},
#  {'producto': 'Lavadora', 'precio': 67.2, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 84.5, 'cantidad': 11.0},
#  {'producto': 'Aspiradora', 'precio': 104.86, 'cantidad': 8.0},
#  {'producto': 'Cafetera', 'precio': 51.16, 'cantidad': 12.0},
#  {'producto': 'Consola de videojuegos', 'precio': 87.23, 'cantidad': 5.0},
#  {'producto': 'Cuadro decorativo', 'precio': 29.17, 'cantidad': 1.0},
#  {'producto': 'Elementos de cerámica', 'precio': 83.81, 'cantidad': 6.0},
#  {'producto': 'Jarrón decorativo', 'precio': 26.97, 'cantidad': 5.0},
#  {'producto': 'Secadora', 'precio': 91.54, 'cantidad': 2.0},
#  {'producto': 'Cafetera', 'precio': 45.98, 'cantidad': 3.0},
#  {'producto': 'Freidora eléctrica', 'precio': 48.68, 'cantidad': 8.0},
#  {'producto': 'Adorno de pared', 'precio': 51.56, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 26.42, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 96.37, 'cantidad': 5.0},
#  {'producto': 'Elementos de cerámica', 'precio': 117.34, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 86.79, 'cantidad': 3.0},
#  {'producto': 'Consola de videojuegos', 'precio': 102.4, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 57.35, 'cantidad': 12.0},
#  {'producto': 'Jarrón decorativo', 'precio': 66.27, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 90.87, 'cantidad': 4.0},
#  {'producto': 'Rincón de plantas', 'precio': 89.47, 'cantidad': 2.0},
#  {'producto': 'Lavadora', 'precio': 108.37, 'cantidad': 1.0},
#  {'producto': 'Secadora', 'precio': 40.63, 'cantidad': 3.0},
#  {'producto': 'Horno eléctrico', 'precio': 45.79, 'cantidad': 7.0},
#  {'producto': 'Tablet', 'precio': 27.98, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 91.39, 'cantidad': 7.0},
#  {'producto': 'Smartphone', 'precio': 27.32, 'cantidad': 7.0},
#  {'producto': 'Televisor', 'precio': 26.7, 'cantidad': 9.0},
#  {'producto': 'Alfombra', 'precio': 71.14, 'cantidad': 2.0},
#  {'producto': 'Espejo decorativo', 'precio': 123.22, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 96.94, 'cantidad': 4.0},
#  {'producto': 'Lavadora', 'precio': 66.16, 'cantidad': 4.0},
#  {'producto': 'Microondas', 'precio': 39.45, 'cantidad': 9.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 100.6, 'cantidad': 6.0},
#  {'producto': 'Consola de videojuegos', 'precio': 109.68, 'cantidad': 5.0},
#  {'producto': 'Televisor', 'precio': 77.83, 'cantidad': 8.0},
#  {'producto': 'Proyector', 'precio': 70.1, 'cantidad': 10.0},
#  {'producto': 'Auriculares', 'precio': 93.37, 'cantidad': 10.0},
#  {'producto': 'SmartWatch', 'precio': 29.15, 'cantidad': 2.0},
#  {'producto': 'Espejo decorativo', 'precio': 52.58, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 70.6, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 106.39, 'cantidad': 6.0},
#  {'producto': 'Espejo decorativo', 'precio': 110.02, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 120.32, 'cantidad': 9.0},
#  {'producto': 'Televisor', 'precio': 89.27, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 31.03, 'cantidad': 9.0},
#  {'producto': 'Rincón de plantas', 'precio': 120.32, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 103.79, 'cantidad': 2.0},
#  {'producto': 'Cortinas', 'precio': 37.02, 'cantidad': 5.0},
#  {'producto': 'Plancha de vapor', 'precio': 95.1, 'cantidad': 2.0},
#  {'producto': 'Aspiradora', 'precio': 28.79, 'cantidad': 12.0},
#  {'producto': 'Horno eléctrico', 'precio': 53.46, 'cantidad': 4.0},
#  {'producto': 'Auriculares', 'precio': 47.24, 'cantidad': 9.0},
#  {'producto': 'SmartWatch', 'precio': 54.84, 'cantidad': 1.0},
#  {'producto': 'Televisor', 'precio': 33.19, 'cantidad': 9.0},
#  {'producto': 'Laptop', 'precio': 30.31, 'cantidad': 2.0},
#  {'producto': 'Elementos de cerámica', 'precio': 28.22, 'cantidad': 4.0},
#  {'producto': 'Lámpara de mesa', 'precio': 95.46, 'cantidad': 10.0},
#  {'producto': 'Cuadro decorativo', 'precio': 111.56, 'cantidad': 9.0},
#  {'producto': 'Batidora', 'precio': 103.27, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 34.5, 'cantidad': 1.0},
#  {'producto': 'Laptop', 'precio': 33.07, 'cantidad': 10.0},
#  {'producto': 'Smartphone', 'precio': 115.81, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 29.77, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 88.56, 'cantidad': 8.0},
#  {'producto': 'Lavadora', 'precio': 76.5, 'cantidad': 3.0},
#  {'producto': 'SmartWatch', 'precio': 100.06, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 43.35, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 53.45, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 121.22, 'cantidad': 6.0},
#  {'producto': 'Consola de videojuegos', 'precio': 72.39, 'cantidad': 1.0},
#  {'producto': 'SmartWatch', 'precio': 122.68, 'cantidad': 1.0},
#  {'producto': 'Smartphone', 'precio': 121.0, 'cantidad': 12.0},
#  {'producto': 'Secadora', 'precio': 109.0, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 47.91, 'cantidad': 1.0},
#  {'producto': 'Lavadora', 'precio': 43.52, 'cantidad': 7.0},
#  {'producto': 'Auriculares', 'precio': 56.56, 'cantidad': 4.0},
#  {'producto': 'Smartphone', 'precio': 59.33, 'cantidad': 2.0},
#  {'producto': 'Televisor', 'precio': 94.98, 'cantidad': 2.0},
#  {'producto': 'Tablet', 'precio': 41.96, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 115.2, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 83.1, 'cantidad': 5.0},
#  {'producto': 'Cuadro decorativo', 'precio': 59.6, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 78.89, 'cantidad': 11.0},
#  {'producto': 'Elementos de cerámica', 'precio': 52.17, 'cantidad': 7.0},
#  {'producto': 'Cuadro decorativo', 'precio': 78.93, 'cantidad': 4.0},
#  {'producto': 'Lavadora', 'precio': 92.36, 'cantidad': 1.0},
#  {'producto': 'Plancha de vapor', 'precio': 101.96, 'cantidad': 10.0},
#  {'producto': 'Aspiradora', 'precio': 74.11, 'cantidad': 11.0},
#  {'producto': 'Freidora eléctrica', 'precio': 121.77, 'cantidad': 12.0},
#  {'producto': 'Cafetera', 'precio': 63.54, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 35.74, 'cantidad': 11.0},
#  {'producto': 'Auriculares', 'precio': 119.77, 'cantidad': 5.0},
#  {'producto': 'Laptop', 'precio': 93.91, 'cantidad': 2.0},
#  {'producto': 'Espejo decorativo', 'precio': 44.37, 'cantidad': 2.0},
#  {'producto': 'Rincón de plantas', 'precio': 81.92, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 108.33, 'cantidad': 2.0},
#  {'producto': 'Aspiradora', 'precio': 112.38, 'cantidad': 10.0},
#  {'producto': 'Microondas', 'precio': 89.16, 'cantidad': 5.0},
#  {'producto': 'Proyector', 'precio': 76.17, 'cantidad': 12.0},
#  {'producto': 'Auriculares', 'precio': 123.41, 'cantidad': 8.0},
#  {'producto': 'Consola de videojuegos', 'precio': 89.96, 'cantidad': 2.0},
#  {'producto': 'Adorno de pared', 'precio': 45.84, 'cantidad': 10.0},
#  {'producto': 'Elementos de cerámica', 'precio': 108.86, 'cantidad': 6.0},
#  {'producto': 'Rincón de plantas', 'precio': 27.95, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 41.6, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 47.6, 'cantidad': 10.0},
#  {'producto': 'Proyector', 'precio': 111.74, 'cantidad': 6.0},
#  {'producto': 'Auriculares', 'precio': 26.0, 'cantidad': 9.0},
#  {'producto': 'Smartphone', 'precio': 88.43, 'cantidad': 2.0},
#  {'producto': 'Proyector', 'precio': 62.88, 'cantidad': 7.0},
#  {'producto': 'Laptop', 'precio': 109.23, 'cantidad': 7.0},
#  {'producto': 'SmartWatch', 'precio': 108.99, 'cantidad': 10.0},
#  {'producto': 'Lámpara de mesa', 'precio': 30.03, 'cantidad': 8.0},
#  {'producto': 'Lámpara de mesa', 'precio': 76.33, 'cantidad': 10.0},
#  {'producto': 'Alfombra', 'precio': 51.29, 'cantidad': 2.0},
#  {'producto': 'Secadora', 'precio': 42.81, 'cantidad': 7.0},
#  {'producto': 'Batidora', 'precio': 77.53, 'cantidad': 4.0},
#  {'producto': 'Cámara digital', 'precio': 117.11, 'cantidad': 9.0},
#  {'producto': 'SmartWatch', 'precio': 49.23, 'cantidad': 4.0},
#  {'producto': 'SmartWatch', 'precio': 81.32, 'cantidad': 6.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 110.42, 'cantidad': 2.0},
#  {'producto': 'Jarrón decorativo', 'precio': 104.16, 'cantidad': 10.0},
#  {'producto': 'Espejo decorativo', 'precio': 117.99, 'cantidad': 3.0},
#  {'producto': 'Aspiradora', 'precio': 69.31, 'cantidad': 10.0},
#  {'producto': 'Lavadora', 'precio': 38.61, 'cantidad': 10.0},
#  {'producto': 'Secadora', 'precio': 84.24, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 109.07, 'cantidad': 4.0},
#  {'producto': 'Televisor', 'precio': 49.23, 'cantidad': 4.0},
#  {'producto': 'Jarrón decorativo', 'precio': 70.51, 'cantidad': 12.0},
#  {'producto': 'Adorno de pared', 'precio': 100.32, 'cantidad': 10.0},
#  {'producto': 'Elementos de cerámica', 'precio': 83.52, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 33.9, 'cantidad': 4.0},
#  {'producto': 'Freidora eléctrica', 'precio': 48.52, 'cantidad': 4.0},
#  {'producto': 'Lavadora', 'precio': 123.28, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 81.99, 'cantidad': 1.0},
#  {'producto': 'SmartWatch', 'precio': 72.38, 'cantidad': 1.0},
#  {'producto': 'Laptop', 'precio': 47.57, 'cantidad': 4.0},
#  {'producto': 'Aspiradora', 'precio': 65.0, 'cantidad': 9.0},
#  {'producto': 'Microondas', 'precio': 82.58, 'cantidad': 9.0},
#  {'producto': 'Cafetera', 'precio': 123.27, 'cantidad': 4.0},
#  {'producto': 'Cámara digital', 'precio': 57.81, 'cantidad': 10.0},
#  {'producto': 'SmartWatch', 'precio': 45.98, 'cantidad': 3.0},
#  {'producto': 'Laptop', 'precio': 70.59, 'cantidad': 9.0},
#  {'producto': 'Cámara digital', 'precio': 89.53, 'cantidad': 9.0},
#  {'producto': 'Cámara digital', 'precio': 102.83, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 124.57, 'cantidad': 3.0},
#  {'producto': 'Espejo decorativo', 'precio': 122.11, 'cantidad': 7.0},
#  {'producto': 'Cuadro decorativo', 'precio': 42.09, 'cantidad': 12.0},
#  {'producto': 'Adorno de pared', 'precio': 103.74, 'cantidad': 5.0},
#  {'producto': 'Alfombra', 'precio': 102.72, 'cantidad': 2.0},
#  {'producto': 'Plancha de vapor', 'precio': 48.48, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 109.97, 'cantidad': 2.0},
#  {'producto': 'Aspiradora', 'precio': 124.82, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 42.67, 'cantidad': 6.0},
#  {'producto': 'Espejo decorativo', 'precio': 30.11, 'cantidad': 12.0},
#  {'producto': 'Elementos de cerámica', 'precio': 47.0, 'cantidad': 2.0},
#  {'producto': 'Alfombra', 'precio': 50.02, 'cantidad': 12.0},
#  {'producto': 'Adorno de pared', 'precio': 112.03, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 79.91, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 58.69, 'cantidad': 4.0},
#  {'producto': 'Batidora', 'precio': 79.14, 'cantidad': 10.0},
#  {'producto': 'SmartWatch', 'precio': 64.98, 'cantidad': 11.0},
#  {'producto': 'Lámpara de mesa', 'precio': 58.38, 'cantidad': 4.0},
#  {'producto': 'Freidora eléctrica', 'precio': 95.71, 'cantidad': 4.0},
#  {'producto': 'Freidora eléctrica', 'precio': 51.37, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 54.54, 'cantidad': 9.0},
#  {'producto': 'SmartWatch', 'precio': 97.01, 'cantidad': 4.0},
#  {'producto': 'SmartWatch', 'precio': 110.23, 'cantidad': 11.0},
#  {'producto': 'Alfombra', 'precio': 78.47, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 52.83, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 99.71, 'cantidad': 3.0},
#  {'producto': 'Elementos de cerámica', 'precio': 116.82, 'cantidad': 3.0},
#  {'producto': 'Adorno de pared', 'precio': 91.48, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 87.04, 'cantidad': 1.0},
#  {'producto': 'Aspiradora', 'precio': 26.11, 'cantidad': 9.0},
#  {'producto': 'Secadora', 'precio': 45.43, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 115.57, 'cantidad': 12.0},
#  {'producto': 'Smartphone', 'precio': 49.34, 'cantidad': 12.0},
#  {'producto': 'Smartphone', 'precio': 59.33, 'cantidad': 5.0},
#  {'producto': 'Smartphone', 'precio': 74.8, 'cantidad': 5.0},
#  {'producto': 'Smartphone', 'precio': 97.62, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 81.16, 'cantidad': 2.0},
#  {'producto': 'Alfombra', 'precio': 108.67, 'cantidad': 4.0},
#  {'producto': 'Elementos de cerámica', 'precio': 35.97, 'cantidad': 2.0},
#  {'producto': 'Cuadro decorativo', 'precio': 109.69, 'cantidad': 8.0},
#  {'producto': 'Plancha de vapor', 'precio': 101.57, 'cantidad': 10.0},
#  {'producto': 'Freidora eléctrica', 'precio': 83.07, 'cantidad': 6.0},
#  {'producto': 'Consola de videojuegos', 'precio': 110.79, 'cantidad': 8.0},
#  {'producto': 'Televisor', 'precio': 112.58, 'cantidad': 5.0},
#  {'producto': 'Cuadro decorativo', 'precio': 71.97, 'cantidad': 12.0},
#  {'producto': 'Cuadro decorativo', 'precio': 72.08, 'cantidad': 11.0},
#  {'producto': 'Adorno de pared', 'precio': 37.5, 'cantidad': 3.0},
#  {'producto': 'Microondas', 'precio': 96.35, 'cantidad': 3.0},
#  {'producto': 'Televisor', 'precio': 97.3, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 57.41, 'cantidad': 4.0},
#  {'producto': 'Auriculares', 'precio': 74.7, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 40.19, 'cantidad': 3.0},
#  {'producto': 'Proyector', 'precio': 108.52, 'cantidad': 12.0},
#  {'producto': 'Proyector', 'precio': 26.52, 'cantidad': 3.0},
#  {'producto': 'Proyector', 'precio': 63.33, 'cantidad': 10.0},
#  {'producto': 'Laptop', 'precio': 31.94, 'cantidad': 11.0},
#  {'producto': 'Proyector', 'precio': 33.84, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 113.01, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 92.84, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 64.96, 'cantidad': 1.0},
#  {'producto': 'Jarrón decorativo', 'precio': 82.89, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 79.98, 'cantidad': 2.0},
#  {'producto': 'Secadora', 'precio': 69.17, 'cantidad': 6.0},
#  {'producto': 'Auriculares', 'precio': 45.97, 'cantidad': 12.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 123.36, 'cantidad': 5.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 101.08, 'cantidad': 7.0},
#  {'producto': 'Cuadro decorativo', 'precio': 87.42, 'cantidad': 7.0},
#  {'producto': 'Elementos de cerámica', 'precio': 38.25, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 109.32, 'cantidad': 7.0},
#  {'producto': 'Microondas', 'precio': 98.65, 'cantidad': 2.0},
#  {'producto': 'Televisor', 'precio': 62.8, 'cantidad': 8.0},
#  {'producto': 'Proyector', 'precio': 65.41, 'cantidad': 7.0},
#  {'producto': 'Plancha de vapor', 'precio': 48.23, 'cantidad': 5.0},
#  {'producto': 'Lavadora', 'precio': 120.53, 'cantidad': 5.0},
#  {'producto': 'Cafetera', 'precio': 97.97, 'cantidad': 2.0},
#  {'producto': 'Auriculares', 'precio': 44.56, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 81.96, 'cantidad': 2.0},
#  {'producto': 'Auriculares', 'precio': 39.92, 'cantidad': 4.0},
#  {'producto': 'Elementos de cerámica', 'precio': 108.86, 'cantidad': 6.0},
#  {'producto': 'Espejo decorativo', 'precio': 59.36, 'cantidad': 4.0},
#  {'producto': 'Secadora', 'precio': 64.11, 'cantidad': 4.0},
#  {'producto': 'Microondas', 'precio': 95.91, 'cantidad': 4.0},
#  {'producto': 'Aspiradora', 'precio': 38.1, 'cantidad': 9.0},
#  {'producto': 'Laptop', 'precio': 76.02, 'cantidad': 10.0},
#  {'producto': 'Auriculares', 'precio': 72.37, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 61.61, 'cantidad': 4.0},
#  {'producto': 'Alfombra', 'precio': 36.14, 'cantidad': 8.0},
#  {'producto': 'Cortinas', 'precio': 98.73, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 76.78, 'cantidad': 7.0},
#  {'producto': 'Cuadro decorativo', 'precio': 120.22, 'cantidad': 5.0},
#  {'producto': 'Rincón de plantas', 'precio': 96.23, 'cantidad': 8.0},
#  {'producto': 'Jarrón decorativo', 'precio': 96.35, 'cantidad': 10.0},
#  {'producto': 'Freidora eléctrica', 'precio': 95.5, 'cantidad': 4.0},
#  {'producto': 'Lavadora', 'precio': 96.75, 'cantidad': 3.0},
#  {'producto': 'Plancha de vapor', 'precio': 79.95, 'cantidad': 10.0},
#  {'producto': 'Laptop', 'precio': 61.22, 'cantidad': 2.0},
#  {'producto': 'Televisor', 'precio': 69.69, 'cantidad': 5.0},
#  {'producto': 'Cámara digital', 'precio': 63.35, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 101.38, 'cantidad': 6.0},
#  {'producto': 'Cuadro decorativo', 'precio': 110.99, 'cantidad': 8.0},
#  {'producto': 'Rincón de plantas', 'precio': 74.58, 'cantidad': 11.0},
#  {'producto': 'Rincón de plantas', 'precio': 58.34, 'cantidad': 2.0},
#  {'producto': 'Rincón de plantas', 'precio': 29.09, 'cantidad': 12.0},
#  {'producto': 'Cuadro decorativo', 'precio': 52.23, 'cantidad': 10.0},
#  {'producto': 'Elementos de cerámica', 'precio': 76.94, 'cantidad': 12.0},
#  {'producto': 'Cuadro decorativo', 'precio': 84.63, 'cantidad': 5.0},
#  {'producto': 'Batidora', 'precio': 79.1, 'cantidad': 4.0},
#  {'producto': 'Cafetera', 'precio': 99.1, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 45.67, 'cantidad': 4.0},
#  {'producto': 'Cámara digital', 'precio': 28.16, 'cantidad': 4.0},
#  {'producto': 'Laptop', 'precio': 51.15, 'cantidad': 2.0},
#  {'producto': 'Consola de videojuegos', 'precio': 63.26, 'cantidad': 2.0},
#  {'producto': 'Smartphone', 'precio': 116.25, 'cantidad': 8.0},
#  {'producto': 'Rincón de plantas', 'precio': 59.16, 'cantidad': 11.0},
#  {'producto': 'Rincón de plantas', 'precio': 63.23, 'cantidad': 7.0},
#  {'producto': 'Adorno de pared', 'precio': 90.05, 'cantidad': 1.0},
#  {'producto': 'Freidora eléctrica', 'precio': 117.97, 'cantidad': 6.0},
#  {'producto': 'Secadora', 'precio': 80.16, 'cantidad': 9.0},
#  {'producto': 'Microondas', 'precio': 60.46, 'cantidad': 5.0},
#  {'producto': 'Plancha de vapor', 'precio': 35.94, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 75.08, 'cantidad': 6.0},
#  {'producto': 'Plancha de vapor', 'precio': 45.5, 'cantidad': 12.0},
#  {'producto': 'Smartphone', 'precio': 32.6, 'cantidad': 8.0},
#  {'producto': 'Televisor', 'precio': 49.01, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 53.67, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 63.79, 'cantidad': 1.0},
#  {'producto': 'Rincón de plantas', 'precio': 36.28, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 44.78, 'cantidad': 4.0},
#  {'producto': 'Rincón de plantas', 'precio': 111.8, 'cantidad': 5.0},
#  {'producto': 'Cafetera', 'precio': 124.68, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 53.82, 'cantidad': 7.0},
#  {'producto': 'Laptop', 'precio': 99.0, 'cantidad': 11.0},
#  {'producto': 'Smartphone', 'precio': 59.99, 'cantidad': 12.0},
#  {'producto': 'Cortinas', 'precio': 36.75, 'cantidad': 12.0},
#  {'producto': 'Cuadro decorativo', 'precio': 35.48, 'cantidad': 3.0},
#  {'producto': 'Lámpara de mesa', 'precio': 31.24, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 66.48, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 110.51, 'cantidad': 11.0},
#  {'producto': 'Microondas', 'precio': 52.26, 'cantidad': 8.0},
#  {'producto': 'Proyector', 'precio': 52.52, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 32.58, 'cantidad': 9.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 26.71, 'cantidad': 12.0},
#  {'producto': 'Cámara digital', 'precio': 61.4, 'cantidad': 7.0},
#  {'producto': 'Alfombra', 'precio': 58.82, 'cantidad': 9.0},
#  {'producto': 'Elementos de cerámica', 'precio': 60.17, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 48.58, 'cantidad': 11.0},
#  {'producto': 'Adorno de pared', 'precio': 75.13, 'cantidad': 6.0},
#  {'producto': 'Cafetera', 'precio': 113.84, 'cantidad': 2.0},
#  {'producto': 'Cafetera', 'precio': 68.89, 'cantidad': 6.0},
#  {'producto': 'Horno eléctrico', 'precio': 31.5, 'cantidad': 4.0},
#  {'producto': 'SmartWatch', 'precio': 35.41, 'cantidad': 3.0},
#  {'producto': 'SmartWatch', 'precio': 29.39, 'cantidad': 11.0},
#  {'producto': 'Laptop', 'precio': 29.49, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 28.64, 'cantidad': 2.0},
#  {'producto': 'Microondas', 'precio': 91.81, 'cantidad': 9.0},
#  {'producto': 'Cafetera', 'precio': 76.0, 'cantidad': 7.0},
#  {'producto': 'Auriculares', 'precio': 117.03, 'cantidad': 6.0},
#  {'producto': 'Televisor', 'precio': 70.17, 'cantidad': 7.0},
#  {'producto': 'Proyector', 'precio': 74.59, 'cantidad': 4.0},
#  {'producto': 'SmartWatch', 'precio': 47.21, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 124.2, 'cantidad': 10.0},
#  {'producto': 'Lámpara de mesa', 'precio': 106.58, 'cantidad': 3.0},
#  {'producto': 'Elementos de cerámica', 'precio': 67.37, 'cantidad': 2.0},
#  {'producto': 'Plancha de vapor', 'precio': 45.37, 'cantidad': 6.0},
#  {'producto': 'Proyector', 'precio': 65.89, 'cantidad': 4.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 62.77, 'cantidad': 6.0},
#  {'producto': 'Cuadro decorativo', 'precio': 106.12, 'cantidad': 3.0},
#  {'producto': 'Lámpara de mesa', 'precio': 62.47, 'cantidad': 6.0},
#  {'producto': 'Lámpara de mesa', 'precio': 46.25, 'cantidad': 12.0},
#  {'producto': 'Lavadora', 'precio': 67.17, 'cantidad': 9.0},
#  {'producto': 'Cafetera', 'precio': 92.62, 'cantidad': 8.0},
#  {'producto': 'Lavadora', 'precio': 46.18, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 49.32, 'cantidad': 3.0},
#  {'producto': 'Tablet', 'precio': 82.71, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 31.09, 'cantidad': 1.0},
#  {'producto': 'Tablet', 'precio': 99.82, 'cantidad': 8.0},
#  {'producto': 'Alfombra', 'precio': 87.85, 'cantidad': 2.0},
#  {'producto': 'Adorno de pared', 'precio': 27.92, 'cantidad': 5.0},
#  {'producto': 'Cuadro decorativo', 'precio': 112.56, 'cantidad': 9.0},
#  {'producto': 'Secadora', 'precio': 41.84, 'cantidad': 8.0},
#  {'producto': 'Cafetera', 'precio': 100.92, 'cantidad': 1.0},
#  {'producto': 'Plancha de vapor', 'precio': 122.77, 'cantidad': 10.0},
#  {'producto': 'Batidora', 'precio': 69.74, 'cantidad': 8.0},
#  {'producto': 'Microondas', 'precio': 108.34, 'cantidad': 12.0},
#  {'producto': 'Batidora', 'precio': 63.5, 'cantidad': 3.0},
#  {'producto': 'Consola de videojuegos', 'precio': 81.69, 'cantidad': 4.0},
#  {'producto': 'Auriculares', 'precio': 104.59, 'cantidad': 9.0},
#  {'producto': 'Cámara digital', 'precio': 117.71, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 119.69, 'cantidad': 10.0},
#  {'producto': 'Jarrón decorativo', 'precio': 108.99, 'cantidad': 6.0},
#  {'producto': 'Cuadro decorativo', 'precio': 34.33, 'cantidad': 11.0},
#  {'producto': 'Batidora', 'precio': 122.02, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 114.48, 'cantidad': 4.0},
#  {'producto': 'Aspiradora', 'precio': 88.95, 'cantidad': 11.0},
#  {'producto': 'Tablet', 'precio': 78.87, 'cantidad': 5.0},
#  {'producto': 'Smartphone', 'precio': 116.89, 'cantidad': 6.0},
#  {'producto': 'Lámpara de mesa', 'precio': 85.58, 'cantidad': 11.0},
#  {'producto': 'Batidora', 'precio': 82.18, 'cantidad': 6.0},
#  {'producto': 'Microondas', 'precio': 54.11, 'cantidad': 7.0},
#  {'producto': 'Proyector', 'precio': 66.66, 'cantidad': 6.0},
#  {'producto': 'Elementos de cerámica', 'precio': 92.88, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 39.63, 'cantidad': 2.0},
#  {'producto': 'Jarrón decorativo', 'precio': 80.34, 'cantidad': 7.0},
#  {'producto': 'Rincón de plantas', 'precio': 85.49, 'cantidad': 2.0},
#  {'producto': 'Batidora', 'precio': 61.72, 'cantidad': 8.0},
#  {'producto': 'Televisor', 'precio': 81.31, 'cantidad': 9.0},
#  {'producto': 'Televisor', 'precio': 123.48, 'cantidad': 7.0},
#  {'producto': 'Cámara digital', 'precio': 31.52, 'cantidad': 8.0},
#  {'producto': 'Rincón de plantas', 'precio': 70.24, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 122.97, 'cantidad': 5.0},
#  {'producto': 'Espejo decorativo', 'precio': 64.37, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 77.65, 'cantidad': 1.0},
#  {'producto': 'Alfombra', 'precio': 118.35, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 55.2, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 108.74, 'cantidad': 3.0},
#  {'producto': 'Jarrón decorativo', 'precio': 112.06, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 38.44, 'cantidad': 7.0},
#  {'producto': 'Secadora', 'precio': 33.89, 'cantidad': 7.0},
#  {'producto': 'Freidora eléctrica', 'precio': 109.97, 'cantidad': 7.0},
#  {'producto': 'Cafetera', 'precio': 106.32, 'cantidad': 1.0},
#  {'producto': 'Proyector', 'precio': 77.06, 'cantidad': 1.0},
#  {'producto': 'Adorno de pared', 'precio': 44.91, 'cantidad': 1.0},
#  {'producto': 'Jarrón decorativo', 'precio': 57.23, 'cantidad': 5.0},
#  {'producto': 'Jarrón decorativo', 'precio': 115.58, 'cantidad': 12.0},
#  {'producto': 'Lavadora', 'precio': 108.53, 'cantidad': 10.0},
#  {'producto': 'Secadora', 'precio': 59.04, 'cantidad': 11.0},
#  {'producto': 'Freidora eléctrica', 'precio': 67.75, 'cantidad': 2.0},
#  {'producto': 'Microondas', 'precio': 81.63, 'cantidad': 6.0},
#  {'producto': 'Smartphone', 'precio': 124.01, 'cantidad': 12.0},
#  {'producto': 'Televisor', 'precio': 33.14, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 115.77, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 59.33, 'cantidad': 8.0},
#  {'producto': 'Proyector', 'precio': 40.99, 'cantidad': 2.0},
#  {'producto': 'SmartWatch', 'precio': 100.57, 'cantidad': 9.0},
#  {'producto': 'SmartWatch', 'precio': 100.96, 'cantidad': 10.0},
#  {'producto': 'Televisor', 'precio': 119.68, 'cantidad': 2.0},
#  {'producto': 'Cuadro decorativo', 'precio': 45.04, 'cantidad': 10.0},
#  {'producto': 'Alfombra', 'precio': 44.66, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 34.26, 'cantidad': 11.0},
#  {'producto': 'Horno eléctrico', 'precio': 70.09, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 39.31, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 117.43, 'cantidad': 8.0},
#  {'producto': 'Consola de videojuegos', 'precio': 117.47, 'cantidad': 8.0},
#  {'producto': 'Consola de videojuegos', 'precio': 118.87, 'cantidad': 6.0},
#  {'producto': 'Espejo decorativo', 'precio': 70.36, 'cantidad': 5.0},
#  {'producto': 'Cortinas', 'precio': 84.55, 'cantidad': 5.0},
#  {'producto': 'Rincón de plantas', 'precio': 46.49, 'cantidad': 1.0},
#  {'producto': 'Alfombra', 'precio': 97.14, 'cantidad': 1.0},
#  {'producto': 'Batidora', 'precio': 29.86, 'cantidad': 4.0},
#  {'producto': 'Aspiradora', 'precio': 60.42, 'cantidad': 11.0},
#  {'producto': 'Horno eléctrico', 'precio': 53.29, 'cantidad': 12.0},
#  {'producto': 'Batidora', 'precio': 65.59, 'cantidad': 9.0},
#  {'producto': 'Smartphone', 'precio': 37.11, 'cantidad': 3.0},
#  {'producto': 'Cortinas', 'precio': 39.67, 'cantidad': 2.0},
#  {'producto': 'Adorno de pared', 'precio': 34.68, 'cantidad': 5.0},
#  {'producto': 'Alfombra', 'precio': 102.81, 'cantidad': 9.0},
#  {'producto': 'Alfombra', 'precio': 48.99, 'cantidad': 8.0},
#  {'producto': 'Batidora', 'precio': 48.8, 'cantidad': 11.0},
#  {'producto': 'Microondas', 'precio': 69.57, 'cantidad': 1.0},
#  {'producto': 'Aspiradora', 'precio': 86.29, 'cantidad': 12.0},
#  {'producto': 'Televisor', 'precio': 68.99, 'cantidad': 10.0},
#  {'producto': 'Tablet', 'precio': 54.19, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 79.29, 'cantidad': 6.0},
#  {'producto': 'Auriculares', 'precio': 51.71, 'cantidad': 3.0},
#  {'producto': 'Laptop', 'precio': 39.13, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 118.6, 'cantidad': 11.0},
#  {'producto': 'Jarrón decorativo', 'precio': 51.08, 'cantidad': 11.0},
#  {'producto': 'Lámpara de mesa', 'precio': 96.41, 'cantidad': 11.0},
#  {'producto': 'Elementos de cerámica', 'precio': 29.05, 'cantidad': 10.0},
#  {'producto': 'Rincón de plantas', 'precio': 32.05, 'cantidad': 4.0},
#  {'producto': 'Batidora', 'precio': 85.59, 'cantidad': 5.0},
#  {'producto': 'Batidora', 'precio': 49.37, 'cantidad': 9.0},
#  {'producto': 'Plancha de vapor', 'precio': 28.85, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 96.84, 'cantidad': 11.0},
#  {'producto': 'Freidora eléctrica', 'precio': 77.13, 'cantidad': 4.0},
#  {'producto': 'Plancha de vapor', 'precio': 102.6, 'cantidad': 12.0},
#  {'producto': 'Auriculares', 'precio': 55.17, 'cantidad': 4.0},
#  {'producto': 'Lámpara de mesa', 'precio': 89.87, 'cantidad': 12.0},
#  {'producto': 'Alfombra', 'precio': 65.09, 'cantidad': 5.0},
#  {'producto': 'Plancha de vapor', 'precio': 40.78, 'cantidad': 12.0},
#  {'producto': 'Freidora eléctrica', 'precio': 61.53, 'cantidad': 11.0},
#  {'producto': 'Horno eléctrico', 'precio': 59.05, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 42.94, 'cantidad': 2.0},
#  {'producto': 'Laptop', 'precio': 43.34, 'cantidad': 8.0},
#  {'producto': 'Espejo decorativo', 'precio': 85.04, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 46.89, 'cantidad': 2.0},
#  {'producto': 'Elementos de cerámica', 'precio': 41.55, 'cantidad': 3.0},
#  {'producto': 'Heladera', 'precio': 121.85, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 30.7, 'cantidad': 5.0},
#  {'producto': 'Lavadora', 'precio': 114.72, 'cantidad': 9.0},
#  {'producto': 'Televisor', 'precio': 31.8, 'cantidad': 10.0},
#  {'producto': 'Proyector', 'precio': 76.15, 'cantidad': 11.0},
#  {'producto': 'Espejo decorativo', 'precio': 79.98, 'cantidad': 10.0},
#  {'producto': 'Espejo decorativo', 'precio': 74.95, 'cantidad': 3.0},
#  {'producto': 'Jarrón decorativo', 'precio': 80.88, 'cantidad': 12.0},
#  {'producto': 'Microondas', 'precio': 71.13, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 122.04, 'cantidad': 1.0},
#  {'producto': 'Lavadora', 'precio': 53.77, 'cantidad': 7.0},
#  {'producto': 'Plancha de vapor', 'precio': 76.32, 'cantidad': 5.0},
#  {'producto': 'Heladera', 'precio': 58.45, 'cantidad': 1.0},
#  {'producto': 'Secadora', 'precio': 110.04, 'cantidad': 11.0},
#  {'producto': 'Smartphone', 'precio': 113.88, 'cantidad': 9.0},
#  {'producto': 'Cámara digital', 'precio': 80.06, 'cantidad': 3.0},
#  {'producto': 'SmartWatch', 'precio': 119.73, 'cantidad': 12.0},
#  {'producto': 'SmartWatch', 'precio': 89.27, 'cantidad': 6.0},
#  {'producto': 'Adorno de pared', 'precio': 36.55, 'cantidad': 3.0},
#  {'producto': 'Microondas', 'precio': 40.9, 'cantidad': 9.0},
#  {'producto': 'Horno eléctrico', 'precio': 109.73, 'cantidad': 9.0},
#  {'producto': 'Heladera', 'precio': 56.94, 'cantidad': 2.0},
#  {'producto': 'Cafetera', 'precio': 104.66, 'cantidad': 11.0},
#  {'producto': 'Televisor', 'precio': 66.57, 'cantidad': 5.0},
#  {'producto': 'Cámara digital', 'precio': 112.14, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 124.82, 'cantidad': 5.0},
#  {'producto': 'SmartWatch', 'precio': 53.93, 'cantidad': 7.0},
#  {'producto': 'Televisor', 'precio': 56.81, 'cantidad': 9.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 80.25, 'cantidad': 10.0},
#  {'producto': 'Elementos de cerámica', 'precio': 94.94, 'cantidad': 12.0},
#  {'producto': 'Jarrón decorativo', 'precio': 51.39, 'cantidad': 10.0},
#  {'producto': 'Cuadro decorativo', 'precio': 78.76, 'cantidad': 10.0},
#  {'producto': 'Elementos de cerámica', 'precio': 75.27, 'cantidad': 4.0},
#  {'producto': 'Microondas', 'precio': 119.61, 'cantidad': 2.0},
#  {'producto': 'Televisor', 'precio': 55.66, 'cantidad': 3.0},
#  {'producto': 'Consola de videojuegos', 'precio': 122.4, 'cantidad': 1.0},
#  {'producto': 'Auriculares', 'precio': 100.07, 'cantidad': 11.0},
#  {'producto': 'Cámara digital', 'precio': 90.34, 'cantidad': 1.0},
#  {'producto': 'Auriculares', 'precio': 42.5, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 29.14, 'cantidad': 10.0},
#  {'producto': 'Espejo decorativo', 'precio': 78.46, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 115.79, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 51.5, 'cantidad': 1.0},
#  {'producto': 'Batidora', 'precio': 39.73, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 101.57, 'cantidad': 7.0},
#  {'producto': 'Lavadora', 'precio': 31.36, 'cantidad': 7.0},
#  {'producto': 'SmartWatch', 'precio': 99.78, 'cantidad': 1.0},
#  {'producto': 'Consola de videojuegos', 'precio': 108.0, 'cantidad': 9.0},
#  {'producto': 'Smartphone', 'precio': 105.63, 'cantidad': 6.0},
#  {'producto': 'Proyector', 'precio': 120.5, 'cantidad': 4.0},
#  {'producto': 'Proyector', 'precio': 89.06, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 70.89, 'cantidad': 11.0},
#  {'producto': 'Lámpara de mesa', 'precio': 29.32, 'cantidad': 3.0},
#  {'producto': 'Jarrón decorativo', 'precio': 98.11, 'cantidad': 2.0},
#  {'producto': 'Horno eléctrico', 'precio': 116.21, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 102.32, 'cantidad': 2.0},
#  {'producto': 'Batidora', 'precio': 111.44, 'cantidad': 3.0},
#  {'producto': 'Lavadora', 'precio': 33.31, 'cantidad': 10.0},
#  {'producto': 'Auriculares', 'precio': 70.16, 'cantidad': 11.0},
#  {'producto': 'Cámara digital', 'precio': 45.12, 'cantidad': 6.0},
#  {'producto': 'Cámara digital', 'precio': 92.0, 'cantidad': 10.0},
#  {'producto': 'Rincón de plantas', 'precio': 101.62, 'cantidad': 9.0},
#  {'producto': 'Elementos de cerámica', 'precio': 97.51, 'cantidad': 5.0},
#  {'producto': 'Alfombra', 'precio': 96.21, 'cantidad': 11.0},
#  {'producto': 'Cuadro decorativo', 'precio': 55.89, 'cantidad': 10.0},
#  {'producto': 'Cortinas', 'precio': 63.98, 'cantidad': 11.0},
#  {'producto': 'Aspiradora', 'precio': 80.38, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 78.28, 'cantidad': 6.0},
#  {'producto': 'Auriculares', 'precio': 101.08, 'cantidad': 10.0},
#  {'producto': 'Laptop', 'precio': 40.16, 'cantidad': 3.0},
#  {'producto': 'Smartphone', 'precio': 107.84, 'cantidad': 11.0},
#  {'producto': 'Jarrón decorativo', 'precio': 109.29, 'cantidad': 10.0},
#  {'producto': 'Lámpara de mesa', 'precio': 40.05, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 103.06, 'cantidad': 9.0},
#  {'producto': 'Microondas', 'precio': 72.86, 'cantidad': 10.0},
#  {'producto': 'Horno eléctrico', 'precio': 82.36, 'cantidad': 2.0},
#  {'producto': 'Cámara digital', 'precio': 68.66, 'cantidad': 12.0},
#  {'producto': 'Cámara digital', 'precio': 85.45, 'cantidad': 3.0},
#  {'producto': 'Cámara digital', 'precio': 65.62, 'cantidad': 8.0},
#  {'producto': 'Elementos de cerámica', 'precio': 89.17, 'cantidad': 4.0},
#  {'producto': 'Cortinas', 'precio': 73.65, 'cantidad': 2.0},
#  {'producto': 'Jarrón decorativo', 'precio': 112.4, 'cantidad': 9.0},
#  {'producto': 'Cortinas', 'precio': 64.93, 'cantidad': 10.0},
#  {'producto': 'Alfombra', 'precio': 48.79, 'cantidad': 11.0},
#  {'producto': 'Adorno de pared', 'precio': 116.42, 'cantidad': 6.0},
#  {'producto': 'Freidora eléctrica', 'precio': 88.59, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 43.14, 'cantidad': 12.0},
#  {'producto': 'Televisor', 'precio': 34.89, 'cantidad': 12.0},
#  {'producto': 'Consola de videojuegos', 'precio': 54.04, 'cantidad': 8.0},
#  {'producto': 'Alfombra', 'precio': 115.12, 'cantidad': 12.0},
#  {'producto': 'Adorno de pared', 'precio': 79.13, 'cantidad': 7.0},
#  {'producto': 'Plancha de vapor', 'precio': 76.04, 'cantidad': 5.0},
#  {'producto': 'Horno eléctrico', 'precio': 103.51, 'cantidad': 7.0},
#  {'producto': 'Horno eléctrico', 'precio': 116.79, 'cantidad': 12.0},
#  {'producto': 'Freidora eléctrica', 'precio': 87.85, 'cantidad': 4.0},
#  {'producto': 'Consola de videojuegos', 'precio': 44.36, 'cantidad': 10.0},
#  {'producto': 'Consola de videojuegos', 'precio': 50.77, 'cantidad': 10.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 32.86, 'cantidad': 11.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 88.65, 'cantidad': 9.0},
#  {'producto': 'Laptop', 'precio': 27.65, 'cantidad': 11.0},
#  {'producto': 'Alfombra', 'precio': 63.14, 'cantidad': 2.0},
#  {'producto': 'Adorno de pared', 'precio': 96.59, 'cantidad': 6.0},
#  {'producto': 'Alfombra', 'precio': 36.17, 'cantidad': 1.0},
#  {'producto': 'Heladera', 'precio': 103.34, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 124.0, 'cantidad': 5.0},
#  {'producto': 'Proyector', 'precio': 116.66, 'cantidad': 12.0},
#  {'producto': 'Consola de videojuegos', 'precio': 94.73, 'cantidad': 1.0},
#  {'producto': 'Televisor', 'precio': 40.83, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 124.63, 'cantidad': 10.0},
#  {'producto': 'Smartphone', 'precio': 114.94, 'cantidad': 11.0},
#  {'producto': 'Horno eléctrico', 'precio': 53.09, 'cantidad': 3.0},
#  {'producto': 'Plancha de vapor', 'precio': 68.28, 'cantidad': 9.0},
#  {'producto': 'Laptop', 'precio': 68.84, 'cantidad': 11.0},
#  {'producto': 'Adorno de pared', 'precio': 71.67, 'cantidad': 4.0},
#  {'producto': 'Rincón de plantas', 'precio': 63.1, 'cantidad': 11.0},
#  {'producto': 'Heladera', 'precio': 112.52, 'cantidad': 4.0},
#  {'producto': 'Heladera', 'precio': 31.42, 'cantidad': 1.0},
#  {'producto': 'Aspiradora', 'precio': 102.92, 'cantidad': 5.0},
# ...
#  {'producto': 'Microondas', 'precio': 32.18, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 123.72, 'cantidad': 3.0},
#  {'producto': 'Televisor', 'precio': 55.97, 'cantidad': 7.0},
#  {'producto': 'Auriculares', 'precio': 47.12, 'cantidad': 12.0},
#  {'producto': 'SmartWatch', 'precio': 115.3, 'cantidad': 3.0},
#  {'producto': 'Laptop', 'precio': 122.13, 'cantidad': 11.0},
#  {'producto': 'Lámpara de mesa', 'precio': 44.88, 'cantidad': 1.0},
#  {'producto': 'Plancha de vapor', 'precio': 33.15, 'cantidad': 2.0},
#  {'producto': 'Freidora eléctrica', 'precio': 44.33, 'cantidad': 10.0},
#  {'producto': 'Auriculares', 'precio': 120.46, 'cantidad': 8.0},
#  {'producto': 'Tablet', 'precio': 35.84, 'cantidad': 11.0},
#  {'producto': 'Laptop', 'precio': 71.74, 'cantidad': 8.0},
#  {'producto': 'Smartphone', 'precio': 111.41, 'cantidad': 7.0},
#  {'producto': 'Tablet', 'precio': 75.89, 'cantidad': 11.0},
#  {'producto': 'Cortinas', 'precio': 98.15, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 41.81, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 33.37, 'cantidad': 3.0},
#  {'producto': 'Jarrón decorativo', 'precio': 53.53, 'cantidad': 7.0},
#  {'producto': 'Jarrón decorativo', 'precio': 40.48, 'cantidad': 11.0},
#  {'producto': 'Freidora eléctrica', 'precio': 95.13, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 84.29, 'cantidad': 10.0},
#  {'producto': 'Microondas', 'precio': 112.89, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 116.78, 'cantidad': 6.0},
#  {'producto': 'Televisor', 'precio': 101.98, 'cantidad': 7.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 77.95, 'cantidad': 6.0},
#  {'producto': 'Adorno de pared', 'precio': 87.52, 'cantidad': 8.0},
#  {'producto': 'Cuadro decorativo', 'precio': 27.99, 'cantidad': 5.0},
#  {'producto': 'Heladera', 'precio': 58.58, 'cantidad': 4.0},
#  {'producto': 'Consola de videojuegos', 'precio': 102.41, 'cantidad': 5.0},
#  {'producto': 'Smartphone', 'precio': 103.69, 'cantidad': 1.0},
#  {'producto': 'Auriculares', 'precio': 89.29, 'cantidad': 2.0},
#  {'producto': 'Alfombra', 'precio': 72.91, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 34.64, 'cantidad': 12.0},
#  {'producto': 'Cafetera', 'precio': 42.4, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 110.21, 'cantidad': 4.0},
#  {'producto': 'Horno eléctrico', 'precio': 27.61, 'cantidad': 6.0},
#  {'producto': 'Cafetera', 'precio': 58.68, 'cantidad': 4.0},
#  {'producto': 'Secadora', 'precio': 39.42, 'cantidad': 9.0},
#  {'producto': 'Batidora', 'precio': 121.14, 'cantidad': 3.0},
#  {'producto': 'Microondas', 'precio': 96.24, 'cantidad': 4.0},
#  {'producto': 'Cortinas', 'precio': 27.05, 'cantidad': 3.0},
#  {'producto': 'Lámpara de mesa', 'precio': 98.22, 'cantidad': 4.0},
#  {'producto': 'Lámpara de mesa', 'precio': 35.26, 'cantidad': 9.0},
#  {'producto': 'Adorno de pared', 'precio': 64.18, 'cantidad': 7.0},
#  {'producto': 'Espejo decorativo', 'precio': 43.51, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 39.86, 'cantidad': 6.0},
#  {'producto': 'Cafetera', 'precio': 91.58, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 99.08, 'cantidad': 11.0},
#  {'producto': 'Freidora eléctrica', 'precio': 82.46, 'cantidad': 4.0},
#  {'producto': 'Horno eléctrico', 'precio': 40.58, 'cantidad': 5.0},
#  {'producto': 'SmartWatch', 'precio': 38.84, 'cantidad': 7.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 70.68, 'cantidad': 5.0},
#  {'producto': 'Televisor', 'precio': 81.42, 'cantidad': 9.0},
#  {'producto': 'Cuadro decorativo', 'precio': 87.93, 'cantidad': 11.0},
#  {'producto': 'Elementos de cerámica', 'precio': 61.12, 'cantidad': 9.0},
#  {'producto': 'Adorno de pared', 'precio': 49.3, 'cantidad': 2.0},
#  {'producto': 'Adorno de pared', 'precio': 33.1, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 86.82, 'cantidad': 10.0},
#  {'producto': 'Horno eléctrico', 'precio': 116.05, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 31.56, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 68.97, 'cantidad': 8.0},
#  {'producto': 'Tablet', 'precio': 74.39, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 66.24, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 114.83, 'cantidad': 9.0},
#  {'producto': 'Jarrón decorativo', 'precio': 87.94, 'cantidad': 2.0},
#  {'producto': 'Cafetera', 'precio': 62.23, 'cantidad': 1.0},
#  {'producto': 'Auriculares', 'precio': 32.81, 'cantidad': 11.0},
#  {'producto': 'SmartWatch', 'precio': 70.66, 'cantidad': 7.0},
#  {'producto': 'Alfombra', 'precio': 41.72, 'cantidad': 8.0},
#  {'producto': 'Adorno de pared', 'precio': 67.75, 'cantidad': 9.0},
#  {'producto': 'Lámpara de mesa', 'precio': 35.43, 'cantidad': 2.0},
#  {'producto': 'Cortinas', 'precio': 84.04, 'cantidad': 3.0},
#  {'producto': 'Lámpara de mesa', 'precio': 76.32, 'cantidad': 7.0},
#  {'producto': 'Secadora', 'precio': 69.58, 'cantidad': 7.0},
#  {'producto': 'Secadora', 'precio': 33.55, 'cantidad': 3.0},
#  {'producto': 'Aspiradora', 'precio': 115.24, 'cantidad': 3.0},
#  {'producto': 'Aspiradora', 'precio': 87.32, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 100.69, 'cantidad': 7.0},
#  {'producto': 'SmartWatch', 'precio': 79.37, 'cantidad': 10.0},
#  {'producto': 'Proyector', 'precio': 120.34, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 40.76, 'cantidad': 8.0},
#  {'producto': 'Alfombra', 'precio': 56.78, 'cantidad': 9.0},
#  {'producto': 'Rincón de plantas', 'precio': 77.3, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 72.5, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 71.17, 'cantidad': 10.0},
#  {'producto': 'Heladera', 'precio': 88.78, 'cantidad': 2.0},
#  {'producto': 'Secadora', 'precio': 42.59, 'cantidad': 12.0},
#  {'producto': 'Auriculares', 'precio': 122.56, 'cantidad': 6.0},
#  {'producto': 'Laptop', 'precio': 83.25, 'cantidad': 6.0},
#  {'producto': 'Laptop', 'precio': 30.16, 'cantidad': 6.0},
#  {'producto': 'Smartphone', 'precio': 123.6, 'cantidad': 12.0},
#  {'producto': 'Jarrón decorativo', 'precio': 94.75, 'cantidad': 1.0},
#  {'producto': 'Freidora eléctrica', 'precio': 38.12, 'cantidad': 2.0},
#  {'producto': 'Auriculares', 'precio': 92.91, 'cantidad': 11.0},
#  {'producto': 'Laptop', 'precio': 124.95, 'cantidad': 11.0},
#  {'producto': 'Laptop', 'precio': 34.74, 'cantidad': 1.0},
#  {'producto': 'Auriculares', 'precio': 87.29, 'cantidad': 2.0},
#  {'producto': 'Lavadora', 'precio': 87.65, 'cantidad': 2.0},
#  {'producto': 'Aspiradora', 'precio': 34.1, 'cantidad': 3.0},
#  {'producto': 'Freidora eléctrica', 'precio': 103.64, 'cantidad': 10.0},
#  {'producto': 'Batidora', 'precio': 88.23, 'cantidad': 11.0},
#  {'producto': 'Televisor', 'precio': 34.23, 'cantidad': 4.0},
#  {'producto': 'Rincón de plantas', 'precio': 102.85, 'cantidad': 3.0},
#  {'producto': 'Lámpara de mesa', 'precio': 96.45, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 119.55, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 42.74, 'cantidad': 12.0},
#  {'producto': 'Adorno de pared', 'precio': 66.0, 'cantidad': 4.0},
#  {'producto': 'Elementos de cerámica', 'precio': 52.97, 'cantidad': 2.0},
#  {'producto': 'Lavadora', 'precio': 49.69, 'cantidad': 12.0},
#  {'producto': 'Secadora', 'precio': 124.09, 'cantidad': 4.0},
#  {'producto': 'Lavadora', 'precio': 37.2, 'cantidad': 10.0},
#  {'producto': 'Cafetera', 'precio': 31.94, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 76.06, 'cantidad': 9.0},
#  {'producto': 'Freidora eléctrica', 'precio': 88.9, 'cantidad': 6.0},
#  {'producto': 'Batidora', 'precio': 38.51, 'cantidad': 9.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 79.11, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 122.8, 'cantidad': 3.0},
#  {'producto': 'Rincón de plantas', 'precio': 60.89, 'cantidad': 1.0},
#  {'producto': 'Cortinas', 'precio': 26.29, 'cantidad': 7.0},
#  {'producto': 'Batidora', 'precio': 123.83, 'cantidad': 12.0},
#  {'producto': 'Cafetera', 'precio': 101.98, 'cantidad': 2.0},
#  {'producto': 'Consola de videojuegos', 'precio': 46.08, 'cantidad': 7.0},
#  {'producto': 'SmartWatch', 'precio': 80.84, 'cantidad': 8.0},
#  {'producto': 'Tablet', 'precio': 63.88, 'cantidad': 8.0},
#  {'producto': 'Tablet', 'precio': 95.9, 'cantidad': 2.0},
#  {'producto': 'Elementos de cerámica', 'precio': 93.84, 'cantidad': 8.0},
#  {'producto': 'Cuadro decorativo', 'precio': 78.91, 'cantidad': 8.0},
#  {'producto': 'Aspiradora', 'precio': 68.73, 'cantidad': 5.0},
#  {'producto': 'Televisor', 'precio': 54.4, 'cantidad': 5.0},
#  {'producto': 'Televisor', 'precio': 52.6, 'cantidad': 2.0},
#  {'producto': 'Lámpara de mesa', 'precio': 55.79, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 50.98, 'cantidad': 3.0},
#  {'producto': 'Heladera', 'precio': 62.93, 'cantidad': 1.0},
#  {'producto': 'Cafetera', 'precio': 58.81, 'cantidad': 10.0},
#  {'producto': 'Plancha de vapor', 'precio': 56.8, 'cantidad': 8.0},
#  {'producto': 'Cafetera', 'precio': 118.03, 'cantidad': 5.0},
#  {'producto': 'Secadora', 'precio': 42.03, 'cantidad': 11.0},
#  {'producto': 'Consola de videojuegos', 'precio': 122.79, 'cantidad': 6.0},
#  {'producto': 'Cámara digital', 'precio': 60.29, 'cantidad': 6.0},
#  {'producto': 'Tablet', 'precio': 117.89, 'cantidad': 1.0},
#  {'producto': 'Cámara digital', 'precio': 63.89, 'cantidad': 1.0},
#  {'producto': 'Alfombra', 'precio': 107.8, 'cantidad': 7.0},
#  {'producto': 'Cortinas', 'precio': 71.03, 'cantidad': 7.0},
#  {'producto': 'Horno eléctrico', 'precio': 122.69, 'cantidad': 10.0},
#  {'producto': 'Secadora', 'precio': 105.8, 'cantidad': 3.0},
#  {'producto': 'Cafetera', 'precio': 88.26, 'cantidad': 1.0},
#  {'producto': 'Proyector', 'precio': 124.37, 'cantidad': 8.0},
#  {'producto': 'Proyector', 'precio': 34.39, 'cantidad': 7.0},
#  {'producto': 'Cámara digital', 'precio': 42.17, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 32.0, 'cantidad': 1.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 98.28, 'cantidad': 5.0},
#  {'producto': 'Elementos de cerámica', 'precio': 45.86, 'cantidad': 6.0},
#  {'producto': 'Alfombra', 'precio': 45.21, 'cantidad': 6.0},
#  {'producto': 'Jarrón decorativo', 'precio': 94.59, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 99.85, 'cantidad': 3.0},
#  {'producto': 'Cortinas', 'precio': 107.96, 'cantidad': 9.0},
#  {'producto': 'Cortinas', 'precio': 45.79, 'cantidad': 7.0},
#  {'producto': 'Aspiradora', 'precio': 69.06, 'cantidad': 11.0},
#  {'producto': 'Cafetera', 'precio': 37.32, 'cantidad': 2.0},
#  {'producto': 'Aspiradora', 'precio': 51.46, 'cantidad': 4.0},
#  {'producto': 'Laptop', 'precio': 104.48, 'cantidad': 5.0},
#  {'producto': 'Laptop', 'precio': 77.38, 'cantidad': 1.0},
#  {'producto': 'Smartphone', 'precio': 76.29, 'cantidad': 11.0},
#  {'producto': 'Lámpara de mesa', 'precio': 61.03, 'cantidad': 6.0},
#  {'producto': 'Espejo decorativo', 'precio': 76.31, 'cantidad': 5.0},
#  {'producto': 'Horno eléctrico', 'precio': 65.16, 'cantidad': 4.0},
#  {'producto': 'Batidora', 'precio': 108.94, 'cantidad': 6.0},
#  {'producto': 'Lavadora', 'precio': 37.39, 'cantidad': 1.0},
#  {'producto': 'Microondas', 'precio': 122.22, 'cantidad': 11.0},
#  {'producto': 'Aspiradora', 'precio': 54.94, 'cantidad': 3.0},
#  {'producto': 'Proyector', 'precio': 41.79, 'cantidad': 7.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 83.34, 'cantidad': 7.0},
#  {'producto': 'Consola de videojuegos', 'precio': 49.74, 'cantidad': 9.0},
#  {'producto': 'Auriculares', 'precio': 46.72, 'cantidad': 11.0},
#  {'producto': 'Auriculares', 'precio': 100.58, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 82.25, 'cantidad': 8.0},
#  {'producto': 'Rincón de plantas', 'precio': 38.89, 'cantidad': 2.0},
#  {'producto': 'Batidora', 'precio': 119.03, 'cantidad': 8.0},
#  {'producto': 'Cafetera', 'precio': 67.0, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 29.68, 'cantidad': 1.0},
#  {'producto': 'Microondas', 'precio': 65.99, 'cantidad': 8.0},
#  {'producto': 'Freidora eléctrica', 'precio': 89.52, 'cantidad': 10.0},
#  {'producto': 'Heladera', 'precio': 29.17, 'cantidad': 2.0},
#  {'producto': 'SmartWatch', 'precio': 70.23, 'cantidad': 5.0},
#  {'producto': 'Alfombra', 'precio': 52.55, 'cantidad': 11.0},
#  {'producto': 'Secadora', 'precio': 110.21, 'cantidad': 11.0},
#  {'producto': 'Plancha de vapor', 'precio': 60.38, 'cantidad': 4.0},
#  {'producto': 'Aspiradora', 'precio': 92.52, 'cantidad': 1.0},
#  {'producto': 'Tablet', 'precio': 43.2, 'cantidad': 4.0},
#  {'producto': 'Rincón de plantas', 'precio': 32.26, 'cantidad': 8.0},
#  {'producto': 'Alfombra', 'precio': 112.82, 'cantidad': 9.0},
#  {'producto': 'Aspiradora', 'precio': 110.58, 'cantidad': 4.0},
#  {'producto': 'Batidora', 'precio': 66.73, 'cantidad': 8.0},
#  {'producto': 'Microondas', 'precio': 82.6, 'cantidad': 10.0},
#  {'producto': 'Auriculares', 'precio': 117.6, 'cantidad': 3.0},
#  {'producto': 'Auriculares', 'precio': 73.7, 'cantidad': 10.0},
#  {'producto': 'Rincón de plantas', 'precio': 115.15, 'cantidad': 11.0},
#  {'producto': 'Espejo decorativo', 'precio': 119.87, 'cantidad': 10.0},
#  {'producto': 'Lavadora', 'precio': 118.77, 'cantidad': 8.0},
#  {'producto': 'Plancha de vapor', 'precio': 110.3, 'cantidad': 9.0},
#  {'producto': 'Freidora eléctrica', 'precio': 87.64, 'cantidad': 7.0},
#  {'producto': 'Laptop', 'precio': 36.36, 'cantidad': 7.0},
#  {'producto': 'Smartphone', 'precio': 76.69, 'cantidad': 3.0},
#  {'producto': 'Tablet', 'precio': 53.22, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 95.05, 'cantidad': 1.0},
#  {'producto': 'Cuadro decorativo', 'precio': 119.07, 'cantidad': 12.0},
#  {'producto': 'Espejo decorativo', 'precio': 65.35, 'cantidad': 10.0},
#  {'producto': 'Jarrón decorativo', 'precio': 96.24, 'cantidad': 11.0},
#  {'producto': 'Microondas', 'precio': 90.55, 'cantidad': 4.0},
#  {'producto': 'Plancha de vapor', 'precio': 90.85, 'cantidad': 2.0},
#  {'producto': 'Horno eléctrico', 'precio': 85.42, 'cantidad': 11.0},
#  {'producto': 'Televisor', 'precio': 38.98, 'cantidad': 11.0},
#  {'producto': 'Proyector', 'precio': 87.64, 'cantidad': 2.0},
#  {'producto': 'Smartphone', 'precio': 56.73, 'cantidad': 1.0},
#  {'producto': 'Parlantes Bluetooth', 'precio': 48.89, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 42.17, 'cantidad': 8.0},
#  {'producto': 'Alfombra', 'precio': 91.25, 'cantidad': 2.0},
#  {'producto': 'Cuadro decorativo', 'precio': 47.37, 'cantidad': 9.0},
#  {'producto': 'Rincón de plantas', 'precio': 119.89, 'cantidad': 4.0},
#  {'producto': 'Lámpara de mesa', 'precio': 98.0, 'cantidad': 12.0},
#  {'producto': 'Plancha de vapor', 'precio': 37.94, 'cantidad': 8.0},
#  {'producto': 'Microondas', 'precio': 96.53, 'cantidad': 1.0},
#  {'producto': 'Freidora eléctrica', 'precio': 58.26, 'cantidad': 2.0},
#  {'producto': 'Cámara digital', 'precio': 118.02, 'cantidad': 1.0},
#  {'producto': 'Lámpara de mesa', 'precio': 97.04, 'cantidad': 12.0},
#  {'producto': 'Lámpara de mesa', 'precio': 119.55, 'cantidad': 3.0},
#  {'producto': 'Horno eléctrico', 'precio': 118.26, 'cantidad': 11.0},
#  {'producto': 'Heladera', 'precio': 115.09, 'cantidad': 2.0},
#  {'producto': 'Tablet', 'precio': 81.56, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 38.79, 'cantidad': 7.0},
#  {'producto': 'Jarrón decorativo', 'precio': 39.89, 'cantidad': 2.0},
#  {'producto': 'Alfombra', 'precio': 60.74, 'cantidad': 12.0},
#  {'producto': 'Horno eléctrico', 'precio': 30.51, 'cantidad': 3.0},
#  {'producto': 'Plancha de vapor', 'precio': 73.95, 'cantidad': 4.0},
#  {'producto': 'Cámara digital', 'precio': 46.25, 'cantidad': 8.0},
#  {'producto': 'Televisor', 'precio': 108.25, 'cantidad': 8.0},
#  {'producto': 'Auriculares', 'precio': 49.7, 'cantidad': 3.0},
#  {'producto': 'Televisor', 'precio': 118.65, 'cantidad': 5.0},
#  {'producto': 'Lámpara de mesa', 'precio': 49.91, 'cantidad': 6.0},
#  {'producto': 'Adorno de pared', 'precio': 37.38, 'cantidad': 6.0},
#  {'producto': 'Lámpara de mesa', 'precio': 79.34, 'cantidad': 1.0},
#  {'producto': 'Espejo decorativo', 'precio': 26.33, 'cantidad': 7.0},
#  {'producto': 'Lámpara de mesa', 'precio': 95.05, 'cantidad': 3.0},
#  {'producto': 'Freidora eléctrica', 'precio': 89.99, 'cantidad': 6.0},
#  ...]

# %% [markdown]
# ## Etapa 2 - Actividad 2
#
# ***Transformación de Datos:** Aplicar filtros y transformaciones para crear una tabla de ventas que muestre solo los productos con alto rendimiento.*
#
# ----
#
# ### Posible(s) respuesta(s):
# Obviamente, hay muchas maneras de considerar una venta como "de alto rendimiento". Podemos pensar en dos muy sencillas:
#
# * **Mínimo de ventas:** un producto es "de buen rendimiento" si aparece en al menos una determinada cantidad de operaciones (`ventas ≥ MIN_VENTAS`).
#
# * **Top por ingresos:** los productos que más dinero generaron (`ingresos_totales = suma de importe`).
#
#
# Vamos a implementar ambas:

# %%
# ----------------------------------------------------
# Transformación simple: productos con buen rendimiento
# ----------------------------------------------------
# Requisitos:
#   El DataFrame 'ventas' las con columnas:
#   - producto (str)
#   - cantidad (numérico)
#   - importe  (numérico)
# ----------------------------------------------------

# ----------------------------------------------------
# Parámetros
# ----------------------------------------------------
MIN_VENTAS = 120   # criterio 1
TOP_N      = 10   # criterio 2 (cantidad de productos)


# ----------------------------------------------------
# Validaciones mínimas: ¿Están las columnas?
# ----------------------------------------------------
requeridas = {"producto", "cantidad", "importe"}
faltan = requeridas - set(ventas.columns)
if faltan:
    raise ValueError(f"Faltan columnas requeridas en 'ventas': {faltan}")

# ----------------------------------------------------
# Agregación por producto
# ----------------------------------------------------
tabla_por_producto = (
    ventas.groupby("producto", as_index=False)
          .agg(
              ingresos_totales=("importe", "sum"),
              unidades_totales=("cantidad", "sum"),
              ventas=("producto", "size"),
          )
)

# ----------------------------------------------------
# Ordenamos por ingresos, descendente, sin indice
# ----------------------------------------------------
tabla_ordenada = tabla_por_producto.sort_values("ingresos_totales", ascending=False).reset_index(drop=True)

# ----------------------------------------------------
# Criterio 1: filtro "ventas ≥ MIN_VENTAS"
# ----------------------------------------------------
buen_rendimiento_min_ventas = (
    tabla_ordenada.loc[tabla_ordenada["ventas"] >= MIN_VENTAS]
)

# ----------------------------------------------------
# Criterio 2: Top-N por ingresos (con manejo de umbral)
# Para evitar posibles errores, verificamos cantidad de
# registros, etc. (no es indispensable, pero...suma)
# ----------------------------------------------------
if len(tabla_ordenada) > 0:
    if len(tabla_ordenada) >= TOP_N:
        umbral = float(tabla_ordenada.iloc[TOP_N - 1]["ingresos_totales"])
        top_por_ingresos = tabla_ordenada.loc[tabla_ordenada["ingresos_totales"] >= umbral]
    else:
        top_por_ingresos = tabla_ordenada.copy()
else:
    top_por_ingresos = tabla_ordenada.copy()


# ----------------------------------------------------
# Salida
# ----------------------------------------------------
print()
print("-"*40)
print("Criterio 1: productos con ventas ≥", MIN_VENTAS)
print("-"*40)
display(buen_rendimiento_min_ventas)

print()
print("-"*40)
print(f"Criterio 2: Top-{TOP_N} por ingresos")
print("-"*40)
display(top_por_ingresos)

# Mini resumen
print()
print("-"*40)
print("Resumen")
print("-"*40)

print("Total productos distintos...:", len(tabla_por_producto))
print("Cumplen ventas ≥ MIN_VENTAS :", len(buen_rendimiento_min_ventas))
print(f"En Top-{TOP_N} por ingresos......:", len(top_por_ingresos))
# Out:
# ----------------------------------------
# Criterio 1: productos con ventas ≥ 120
# ----------------------------------------
#           producto  ingresos_totales  unidades_totales  ventas
# 0  Lámpara de mesa          82276.38            1112.0     176
# 1      Auriculares          74175.58             958.0     143
# 2       Microondas          72562.89             912.0     135
# ----------------------------------------
# Criterio 2: Top-10 por ingresos
# ----------------------------------------
#             producto  ingresos_totales  unidades_totales  ventas
# 0    Lámpara de mesa          82276.38            1112.0     176
# 1        Auriculares          74175.58             958.0     143
# 2         Microondas          72562.89             912.0     135
# 3           Cafetera          59607.31             765.0     117
# 4  Cuadro decorativo          54297.60             726.0     100
# 5         Smartphone          54132.44             665.0     101
# 6           Secadora          52115.45             696.0     100
# 7  Jarrón decorativo          51130.88             672.0     100
# 8           Batidora          50979.20             672.0     100
# 9  Rincón de plantas          50456.45             691.0     101
# ----------------------------------------
# Resumen
# ----------------------------------------
# Total productos distintos...: 30
# Cumplen ventas ≥ MIN_VENTAS : 3
# En Top-10 por ingresos......: 10

# %% [markdown]
# ## Etapa 2 - Actividad 3:
#
# ***Agregación:** Resumir las ventas por categoría de producto y analizar los
# ingresos generados.*
#
# #### Opción A — Resumen clásico (ranking y participación)
#
# Muestra ingresos por categoría, volumen y ticket, más % de participación del total.
#
# Este "resumen clásico" es ideal para un **ranking** y para ver rápido **qué categorías traccionan más** (ingresos y %).

# %%
# OPCION A: Resumen "clásico" por categoría

# ----------------------------------------------------
# 1) Agrupar y resumir por categoría
# ----------------------------------------------------
resumen_cat = (
    ventas.groupby('categoria', as_index=False)
          .agg(ingresos=('importe','sum'),
               unidades=('cantidad','sum'),
               transacciones=('id_venta','count'))
          .sort_values('ingresos', ascending=False)
)

# ----------------------------------------------------
# 2) Participación de cada categoría sobre el total
# ----------------------------------------------------
total_ingresos = resumen_cat['ingresos'].sum()
resumen_cat['participacion_%'] = (resumen_cat['ingresos'] / total_ingresos * 100).round(2)

# ----------------------------------------------------
# 3) Ticket promedio por transacción
# ----------------------------------------------------
resumen_cat['ticket_promedio'] = (resumen_cat['ingresos'] / resumen_cat['transacciones']).round(2)

# ----------------------------------------------------
# Mostramos resultados
# ----------------------------------------------------
display(resumen_cat)
# Out:
#            categoria   ingresos  unidades  transacciones  participacion_%  \
# 1  Electrodomésticos  505299.63    6592.0           1000            34.44
# 2        Electrónica  482577.80    6413.0            998            32.89
# 0         Decoración  479216.09    6490.0           1000            32.66
#
#    ticket_promedio
# 1           505.30
# 2           483.54
# 0           479.22

# %% [markdown]
# Veamos "paso a paso" que hace el código anterior:
#
# ### 1) Agrupar y resumir por categoría
#
# * `ventas.groupby('categoria', as_index=False)` junta todas las filas que tienen la **misma categoría** para poder calcular agregados por grupo.
#
# * `as_index=False` hace que la columna `categoria` quede como **columna normal** (no como índice).
#
# * `.agg(...)`calcula, para cada categoría:
#
#   * `ingresos`: suma de `importe` (cuánta plata entró).
#   * `unidades`: suma de `cantidad` (cuántas unidades se vendieron).
#   * `transacciones`: conteo de `id_venta` (cuántas filas/ventas hubo).
#
# * `.sort_values('ingresos', ascending=False)` ordena el resultado de mayor a menor **por ingresos** para ver primero las categorías que más facturan.
#
# Al terminar este bloque, `resumen_cat` es una tabla con 4 columnas: `categoria`, `ingresos`, `unidades`, `transacciones`, ordenada por `ingresos`.
#
#
#
# ### 2) Participación de cada categoría sobre el total
#
# * `total_ingresos` suma todos los ingresos de todas las categorías.
# * `participacion_%` para cada fila, divide el ingreso de esa categoría por el total y lo pasa a **porcentaje**, redondeado a 2 decimales.
#
# > Esto responde: *“¿qué porcentaje del total de ingresos aporta cada categoría?”*
#
#
#
# ### 3) Ticket promedio por transacción
#
# * Calcula **ingreso promedio por venta** (no por unidad). Si una categoría tuvo $1000 de ingresos en 50 ventas, el ticket promedio es $20.
#
#
# ### 4) Mostrar el resultado
#
# * Muestra la tabla final, con `categoria | ingresos | unidades | transacciones | participacion_% | ticket_promedio`.

# %% [markdown]
# #### Opción B — Tendencia temporal (matriz mes x categoría)
#
# Muestra cómo evoluciona el **ingreso mensual** por **categoría**. Permite:
#
# * Ver **estacionalidad** (meses fuertes/débiles por categoría).
# * Detectar **picos** o **caídas** puntuales.
# * Servir de base para **gráficos** rápidos:

# %%
# OPCION B: Ventas mensuales por categoría (matriz)

# ----------------------------------------------------
# 1) Generar la clave temporal "año-mes"
# ----------------------------------------------------
ventas['anio_mes'] = ventas['fecha_venta'].dt.to_period('M').astype(str)

# ----------------------------------------------------
# 2) Armar la matriz "mes x categoría" con los ingresos
# ----------------------------------------------------
tabla_mensual_cat = pd.pivot_table(
    ventas,
    values='importe',
    index='anio_mes',
    columns='categoria',
    aggfunc='sum',
    fill_value=0
).sort_index()

# ----------------------------------------------------
# Mostramos resultados
# ----------------------------------------------------
display(tabla_mensual_cat)
# Out:
# categoria  Decoración  Electrodomésticos  Electrónica
# anio_mes
# 2024-01      47328.61           40504.60     41771.78
# 2024-02      44907.81           34963.72     38800.91
# 2024-03      42796.48           44521.13     49461.54
# 2024-04      42363.49           47045.69     39021.51
# 2024-05      46195.78           55743.24     41788.23
# 2024-06      34997.37           36422.38     37060.42
# 2024-07      34287.87           41420.84     40521.26
# 2024-08      35519.57           41983.60     42176.98
# 2024-09      36128.46           39864.84     39794.55
# 2024-10      34280.27           36940.40     40896.46
# 2024-11      43118.71           42127.54     34705.54
# 2024-12      37291.67           43761.65     36578.62

# %% [markdown]
# Analicemos el código anterior....
#
# ### 1) Generar la clave temporal "año-mes"
#
# * `ventas['fecha_venta']` es `datetime`.
# * `.dt.to_period('M')` lo lleva a **periodos mensuales** (ej. `2024-03`).
# * `.astype(str)` lo convierte a string para que sea una **columna común** y ordenable (formato `YYYY-MM`).
#
# Como resultado, cada fila de venta queda etiquetada con su mes (`anio_mes`).
#
#
#
# ### 2) Armar la **matriz mes x categoría** (ingresos)
#
# * `pd.pivot_table(...)` "reacomoda" la tabla:
#
#   * **index='anio_mes'** hace que hay una fila por cada mes.
#   * **columns='categoria'** crea una columna por cada categoría de producto.
#   * **values='importe'** es cuánto **ingresó** en ese mes para esa categoría.
#   * **aggfunc='sum'** suma los importes (si hay varias ventas en la misma celda).
#   * **fill_value=0** evita el `NaN` si no hubo ventas en esa combinación mes-categoría. Pone **0** en lugar de `NaN`.
# * `.sort_index()` nos asegura el orden cronológico, por `anio_mes`.
#
# Esto da como resultado una **matriz** donde vemos, mes por mes, cuánto facturó cada categoría.
#
#
# ### 3) Mostramos resultados
#
# * Vista de la tabla final, lista para **analizar estacionalidad** y comparar categorías.

# %% [markdown]
# ## Etapa 2 - Actividad 4
#
# ***Integración de Datos:** Combinar los sets de datos de ventas y marketing
# para obtener una visión más amplia de las tendencias.*
#
# Para hacer este punto necesitamos transitar la clase nro 8 (semana próxima) donde veremos como llevar a cabo la combinación de diferentes fuentes de datos en Python, Numpy y Pandas mediante `merge()` y `join()`.
